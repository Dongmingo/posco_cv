# %%
import torch
from torch.utils.data import Dataset
import torch.nn as nn
import os
from torchvision import transforms
import torchvision
import torch.optim as optim
import numpy as np
from sklearn.neighbors import NearestNeighbors
# !pip install pytorch_metric_learning
import PIL
import torch.nn.functional as F
from torchsummary import summary
# Out:
# Requirement already satisfied: pytorch_metric_learning in /root/anaconda3/lib/python3.8/site-packages (1.4.0)
# Requirement already satisfied: torch>=1.6.0 in /root/anaconda3/lib/python3.8/site-packages (from pytorch_metric_learning) (1.10.0)
# Requirement already satisfied: scikit-learn in /root/anaconda3/lib/python3.8/site-packages (from pytorch_metric_learning) (0.24.1)
# Requirement already satisfied: tqdm in /root/anaconda3/lib/python3.8/site-packages (from pytorch_metric_learning) (4.59.0)
# Requirement already satisfied: numpy in /root/anaconda3/lib/python3.8/site-packages (from pytorch_metric_learning) (1.20.1)
# Requirement already satisfied: torchvision in /root/anaconda3/lib/python3.8/site-packages (from pytorch_metric_learning) (0.10.0a0)
# Requirement already satisfied: typing-extensions in /root/anaconda3/lib/python3.8/site-packages (from torch>=1.6.0->pytorch_metric_learning) (3.7.4.3)
# Requirement already satisfied: scipy>=0.19.1 in /root/anaconda3/lib/python3.8/site-packages (from scikit-learn->pytorch_metric_learning) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/anaconda3/lib/python3.8/site-packages (from scikit-learn->pytorch_metric_learning) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /root/anaconda3/lib/python3.8/site-packages (from scikit-learn->pytorch_metric_learning) (1.0.1)
# Requirement already satisfied: pillow>=5.3.0 in /root/anaconda3/lib/python3.8/site-packages (from torchvision->pytorch_metric_learning) (8.2.0)

# %%
##download dataset 
#밑에 코드 주석을 풀면 cub.zip 파일이 다운받아지고 cub라는 폴더가 생깁니다. 
#!wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1o0grxoqCxcrgI6Nd4nxybXulU5IrE8wX' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1o0grxoqCxcrgI6Nd4nxybXulU5IrE8wX" -O CUB.zip && rm -rf /tmp/cookies.txt
#!apt install unzip
#!unzip CUB.zip 
#!mkdir CUB
#!mv train ./CUB
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   zip
# The following NEW packages will be installed:
#   unzip
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 168 kB of archives.
# After this operation, 567 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 unzip amd64 6.0-21ubuntu1.1 [168 kB]
# Fetched 168 kB in 2s (98.7 kB/s)33m
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package unzip.
# (Reading database ... 50332 files and directories currently installed.)
# Preparing to unpack .../unzip_6.0-21ubuntu1.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [ 17%] [#########.................................................] 8Unpacking unzip (6.0-21ubuntu1.1) ...
# 7Progress: [ 33%] [###################.......................................] 87Progress: [ 50%] [#############################.............................] 8Setting up unzip (6.0-21ubuntu1.1) ...
# 7Progress: [ 67%] [######################################....................] 87Progress: [ 83%] [################################################..........] 8Processing triggers for mime-support (3.60ubuntu1) ...
#
# 78Archive:  CUB.zip
#    creating: train/
#   inflating: __MACOSX/._train
#    creating: train/005.Crested_Auklet/
#    creating: train/015.Lazuli_Bunting/
#    creating: train/156.White_eyed_Vireo/
#    creating: train/081.Pied_Kingfisher/
#    creating: train/135.Bank_Swallow/
#    creating: train/200.Common_Yellowthroat/
#    creating: train/086.Pacific_Loon/
#    creating: train/067.Anna_Hummingbird/
#    creating: train/076.Dark_eyed_Junco/
#    creating: train/149.Brown_Thrasher/
#    creating: train/127.Savannah_Sparrow/
#    creating: train/041.Scissor_tailed_Flycatcher/
#    creating: train/141.Artic_Tern/
#    creating: train/082.Ringed_Kingfisher/
#    creating: train/099.Ovenbird/
#    creating: train/013.Bobolink/
#    creating: train/104.American_Pipit/
#    creating: train/023.Brandt_Cormorant/
#    creating: train/168.Kentucky_Warbler/
#    creating: train/072.Pomarine_Jaeger/
#    creating: train/040.Olive_sided_Flycatcher/
#    creating: train/185.Bohemian_Waxwing/
#    creating: train/144.Common_Tern/
#    creating: train/034.Gray_crowned_Rosy_Finch/
#    creating: train/126.Nelson_Sharp_tailed_Sparrow/
#    creating: train/163.Cape_May_Warbler/
#    creating: train/043.Yellow_bellied_Flycatcher/
#    creating: train/084.Red_legged_Kittiwake/
#    creating: train/089.Hooded_Merganser/
#    creating: train/116.Chipping_Sparrow/
#    creating: train/029.American_Crow/
#   inflating: train/.DS_Store
#    creating: train/035.Purple_Finch/
#    creating: train/026.Bronzed_Cowbird/
#    creating: train/114.Black_throated_Sparrow/
#    creating: train/188.Pileated_Woodpecker/
#    creating: train/108.White_necked_Raven/
#    creating: train/158.Bay_breasted_Warbler/
#    creating: train/154.Red_eyed_Vireo/
#    creating: train/047.American_Goldfinch/
#    creating: train/162.Canada_Warbler/
#    creating: train/102.Western_Wood_Pewee/
#    creating: train/096.Hooded_Oriole/
#    creating: train/189.Red_bellied_Woodpecker/
#    creating: train/182.Yellow_Warbler/
#    creating: train/195.Carolina_Wren/
#    creating: train/010.Red_winged_Blackbird/
#    creating: train/017.Cardinal/
#    creating: train/059.California_Gull/
#    creating: train/161.Blue_winged_Warbler/
#    creating: train/004.Groove_billed_Ani/
#    creating: train/190.Red_cockaded_Woodpecker/
#    creating: train/121.Grasshopper_Sparrow/
#    creating: train/080.Green_Kingfisher/
#    creating: train/150.Sage_Thrasher/
#    creating: train/167.Hooded_Warbler/
#    creating: train/119.Field_Sparrow/
#    creating: train/110.Geococcyx/
#    creating: train/122.Harris_Sparrow/
#    creating: train/103.Sayornis/
#    creating: train/077.Tropical_Kingbird/
#    creating: train/197.Marsh_Wren/
#    creating: train/038.Great_Crested_Flycatcher/
#    creating: train/006.Least_Auklet/
#    creating: train/180.Wilson_Warbler/
#    creating: train/146.Forsters_Tern/
#    creating: train/031.Black_billed_Cuckoo/
#    creating: train/045.Northern_Fulmar/
#    creating: train/107.Common_Raven/
#    creating: train/056.Pine_Grosbeak/
#    creating: train/091.Mockingbird/
#    creating: train/196.House_Wren/
#    creating: train/079.Belted_Kingfisher/
#    creating: train/052.Pied_billed_Grebe/
#    creating: train/049.Boat_tailed_Grackle/
#    creating: train/065.Slaty_backed_Gull/
#    creating: train/140.Summer_Tanager/
#    creating: train/130.Tree_Sparrow/
#    creating: train/050.Eared_Grebe/
#    creating: train/071.Long_tailed_Jaeger/
#    creating: train/088.Western_Meadowlark/
#    creating: train/021.Eastern_Towhee/
#    creating: train/128.Seaside_Sparrow/
#    creating: train/063.Ivory_Gull/
#    creating: train/171.Myrtle_Warbler/
#    creating: train/048.European_Goldfinch/
#    creating: train/152.Blue_headed_Vireo/
#    creating: train/186.Cedar_Waxwing/
#    creating: train/094.White_breasted_Nuthatch/
#    creating: train/166.Golden_winged_Warbler/
#    creating: train/118.House_Sparrow/
#    creating: train/173.Orange_crowned_Warbler/
#    creating: train/177.Prothonotary_Warbler/
#    creating: train/139.Scarlet_Tanager/
#    creating: train/187.American_Three_toed_Woodpecker/
#    creating: train/133.White_throated_Sparrow/
#    creating: train/191.Red_headed_Woodpecker/
#    creating: train/101.White_Pelican/
#    creating: train/083.White_breasted_Kingfisher/
#    creating: train/009.Brewer_Blackbird/
#    creating: train/011.Rusty_Blackbird/
#    creating: train/137.Cliff_Swallow/
#    creating: train/192.Downy_Woodpecker/
#    creating: train/157.Yellow_throated_Vireo/
#    creating: train/115.Brewer_Sparrow/
#    creating: train/027.Shiny_Cowbird/
#    creating: train/100.Brown_Pelican/
#    creating: train/134.Cape_Glossy_Starling/
#    creating: train/117.Clay_colored_Sparrow/
#    creating: train/025.Pelagic_Cormorant/
#    creating: train/053.Western_Grebe/
#    creating: train/002.Laysan_Albatross/
#    creating: train/143.Caspian_Tern/
#    creating: train/153.Philadelphia_Vireo/
#    creating: train/014.Indigo_Bunting/
#    creating: train/178.Swainson_Warbler/
#    creating: train/169.Magnolia_Warbler/
#    creating: train/092.Nighthawk/
#    creating: train/109.American_Redstart/
#    creating: train/098.Scott_Oriole/
#    creating: train/159.Black_and_white_Warbler/
#    creating: train/165.Chestnut_sided_Warbler/
#    creating: train/148.Green_tailed_Towhee/
#    creating: train/058.Pigeon_Guillemot/
#    creating: train/155.Warbling_Vireo/
#    creating: train/060.Glaucous_winged_Gull/
#    creating: train/145.Elegant_Tern/
#    creating: train/066.Western_Gull/
#    creating: train/111.Loggerhead_Shrike/
#    creating: train/075.Green_Jay/
#    creating: train/164.Cerulean_Warbler/
#    creating: train/093.Clark_Nutcracker/
#    creating: train/057.Rose_breasted_Grosbeak/
#    creating: train/069.Rufous_Hummingbird/
#    creating: train/012.Yellow_headed_Blackbird/
#    creating: train/062.Herring_Gull/
#    creating: train/183.Northern_Waterthrush/
#    creating: train/055.Evening_Grosbeak/
#    creating: train/184.Louisiana_Waterthrush/
#    creating: train/131.Vesper_Sparrow/
#    creating: train/136.Barn_Swallow/
#    creating: train/064.Ring_billed_Gull/
#    creating: train/174.Palm_Warbler/
#    creating: train/123.Henslow_Sparrow/
#    creating: train/019.Gray_Catbird/
#    creating: train/078.Gray_Kingbird/
#    creating: train/016.Painted_Bunting/
#    creating: train/106.Horned_Puffin/
#    creating: train/120.Fox_Sparrow/
#    creating: train/147.Least_Tern/
#    creating: train/074.Florida_Jay/
#    creating: train/070.Green_Violetear/
#    creating: train/022.Chuck_will_Widow/
#    creating: train/030.Fish_Crow/
#    creating: train/176.Prairie_Warbler/
#    creating: train/024.Red_faced_Cormorant/
#    creating: train/129.Song_Sparrow/
#    creating: train/042.Vermilion_Flycatcher/
#    creating: train/090.Red_breasted_Merganser/
#    creating: train/033.Yellow_billed_Cuckoo/
#    creating: train/001.Black_footed_Albatross/
#   inflating: train/046.Gadwall/Gadwall_0064_31504.jpg
#   inflating: train/046.Gadwall/Gadwall_0029_31637.jpg
#   inflating: train/046.Gadwall/Gadwall_0014_31570.jpg
#   inflating: train/046.Gadwall/Gadwall_0048_31312.jpg
#   inflating: train/046.Gadwall/Gadwall_0066_31557.jpg
#   inflating: train/046.Gadwall/Gadwall_0042_31411.jpg
#   inflating: train/046.Gadwall/Gadwall_0004_31669.jpg
#   inflating: train/046.Gadwall/Gadwall_0097_30893.jpg
#   inflating: train/046.Gadwall/Gadwall_0092_31162.jpg
#   inflating: train/046.Gadwall/Gadwall_0084_31135.jpg
#   inflating: train/046.Gadwall/Gadwall_0077_30929.jpg
#   inflating: train/046.Gadwall/Gadwall_0005_30924.jpg
#   inflating: train/046.Gadwall/Gadwall_0059_31646.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0045_36672.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0004_14988.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0073_37148.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0103_36673.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0094_36995.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0025_36646.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0081_37034.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0078_36655.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0086_36818.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0033_36980.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0104_36984.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0066_36632.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0016_36862.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0038_37095.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0036_37048.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0097_37067.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0111_36841.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0112_36679.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0031_37173.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0048_36809.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0049_37180.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0107_36696.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0015_36985.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0079_36656.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0101_36719.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0037_36794.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0067_36965.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0027_36703.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0024_36680.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0092_36711.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0065_36847.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0041_37174.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0053_36709.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0075_36963.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0061_36633.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0010_37108.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0020_36967.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0019_37205.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0106_36986.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0029_37197.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0093_37107.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0087_36780.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0014_36708.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0082_36991.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0074_37155.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0009_36992.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0023_37069.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0046_37119.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0057_37116.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0051_37065.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0109_36914.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0085_36990.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0042_36742.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0099_36828.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0002_36648.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0071_36948.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0022_37082.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0095_37007.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0072_36774.jpg
#   inflating: train/054.Blue_Grosbeak/Blue_Grosbeak_0043_37200.jpg
# mkdir: cannot create directory ‘CUB’: File exists

# %%
class CUBirds(Dataset):
    def __init__(self, root, mode, transform = None): #root: "./"
        
        self.root = os.path.join(root, "CUB/train")
        self.mode = mode
        self.transform = transform
        
        if self.mode == 'train':
            self.classes = range(0,100)
        elif self.mode == 'eval':
            self.classes = range(100,200)

        self.ys, self.im_paths = [], []
        
        image_folder = torchvision.datasets.ImageFolder(root = self.root) ##imagefolder는 계층적인 폴더 구조를 가지고 있는 데이터셋에 사용할 수 있다. 
        
        for i in image_folder.imgs: 
            # i[0]: image path, i[1]: label
            y = i[1]
            if y in self.classes:
                self.ys += [y]
                self.im_paths.append(i[0])
    
    def __getitem__(self, index):
        
        im = PIL.Image.open(self.im_paths[index]).convert('RGB')
        im = self.transform(im)

        target = self.ys[index]

        return im, target
    
    def __len__(self):
        return len(self.ys)

# %%
transform = torchvision.transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)), 
        transforms.Resize((224, 224))
    ])

##define dataset
train_dataset = CUBirds("./", mode = "train", transform = transform)
val_dataset = CUBirds("./", mode = "eval", transform = transform)
print(len(train_dataset))
print(len(val_dataset))

full_dataset = torch.utils.data.ConcatDataset([train_dataset, val_dataset])
print(len(full_dataset))

# define loader
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64)
full_loader = torch.utils.data.DataLoader(full_dataset, batch_size=64)
# Out:
# 5864
# 5924
# 11788

# %%
len(full_dataset)
# Out:
# 11788

# %%
class Resnet18(nn.Module):
    def __init__(self, embedding_size, pretrained=True):
        super(Resnet18, self).__init__()

        self.model = torchvision.models.resnet18(pretrained = pretrained)
        self.embedding_size = embedding_size
        in_features = self.model.fc.in_features
        
        self.model.embedding = nn.Linear(in_features, self.embedding_size)
        

    def forward(self, x):
        x = self.model.conv1(x)
        x = self.model.bn1(x)
        x = self.model.relu(x)
        x = self.model.maxpool(x)
        x = self.model.layer1(x)
        x = self.model.layer2(x)
        x = self.model.layer3(x)
        x = self.model.layer4(x)
        x = self.model.avgpool(x)

        x = x.view(x.size(0), -1)
        x = self.model.embedding(x) ## embedding the vector to embedding space

        return x

# %%
#define model
device = "cuda:0"
model = Resnet18(512, True)
summary(model, batch_size=-1, input_size=(3, 224, 224), device='cpu')
model = model.to(device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 512]         262,656
# ================================================================
# Total params: 11,439,168
# Trainable params: 11,439,168
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 43.64
# Estimated Total Size (MB): 107.00
# ----------------------------------------------------------------

# %%
class ContrastiveLoss(torch.nn.Module):
    def __init__(self, margin=2.0, num_classes = 200):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
        self.num_classes = num_classes

    def forward(self, output, labels): ##output shape: [batch, embedding_size], labels shape: [Batch,]
        ##compute label matrix
        labels = labels.detach().cpu().numpy()
        num_samples = labels.shape[0]
        mask_multi, target = np.zeros([self.num_classes, num_samples]), 1.0  ##200, 64

        for c in range(self.num_classes):
            c_indices = np.where(labels==c)
            mask_multi[c, c_indices] = target
            
        index_matrix = torch.tensor(mask_multi).to("cuda")
        label = index_matrix[labels] # 64 * 64 
        
        ##compute pairwise euclidean distance
        euclidean_distance = torch.cdist(output, output, p = 2)

        ##define loss equation
        loss_contrastive = torch.mean(label * euclidean_distance + (1-label) * torch.clamp(self.margin - euclidean_distance, min = 0.0))

        return loss_contrastive

# %%
class ContrastiveLoss_easy(torch.nn.Module):
    def __init__(self, margin=2.0, num_classes = 200):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
        self.num_classes = num_classes

    def forward(self, output, labels): ##output shape: [batch, embedding_size], labels shape: [Batch,]
        ##compute label matrix
        label_y = []
        for i in labels:
            ys = []
            for j in labels:
                if i == j:  ## 같으면 레이블 1
                    ys.append(1)
                else:  ## 다르면 레이블 0
                    ys.append(0)
            label_y.append(ys)
        
        label_y = torch.tensor(label_y).cuda() ##텐서로 바꿔주고 지피유로 올려줌
        
        ##compute pairwise euclidean distance
        euclidean_distance = torch.cdist(output, output, p = 2)
        
        ##define loss equation
        loss_contrastive = torch.mean(label_y * euclidean_distance + (1-label_y) * torch.clamp(self.margin - euclidean_distance, min = 0.0))
        
        return loss_contrastive

# %%
##metric learning losses are defined in pytorch_metric_learning package
## many losses are defined in pytorch_metric_learning! try to use other lossses 
# https://github.com/KevinMusgrave/pytorch-metric-learning/tree/master/src/pytorch_metric_learning/losses
# criterion = losses.ContrastiveLoss(neg_margin = 0.5) ##contrastive loss from pytorch github

from pytorch_metric_learning import miners, losses

#define optimizer, criterion
optimizer = optim.Adam(model.parameters(), lr=1e-5) 
criterion = ContrastiveLoss(margin = 2.0, num_classes = 200)  ## custom constrastive loss

# %%
EPOCHS = 1

# Training Loop
for epoch in (range(EPOCHS)):
    running_loss = 0.
    model.train()
    for batch_idx, batch in enumerate(train_loader):
        data, target = batch
        data, target = data.cuda(), target.cuda()
        
        optimizer.zero_grad()
        
        output = model(data)
        
        loss = criterion(output,  target.squeeze())
        running_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        
    train_loss = running_loss/len(train_loader)
    
    print(f"Epochs = {epoch}, Training Loss : {train_loss}")
    
    ##validation
    valid_loss = 0.
    model.eval()
    with torch.no_grad():
        for batch_idx, batch in enumerate(val_loader):
            data, target = batch
            data, target = data.cuda(), target.cuda()
            
            output = model(data)
        
            loss = criterion(output, target.squeeze())
            valid_loss += loss.item()
            
    val_loss = valid_loss/len(val_loader)

    print(f"Epochs = {epoch}, Validation Loss : {val_loss}")
# Out:
# Epochs = 0, Training Loss : 0.10754607866122173
# Epochs = 0, Validation Loss : 6.424152223382171

# %%
## 전체 dataset에 대한 feature vector (embedding)을 구함
def create_embedding(model, full_loader, device):
    model.eval()
    
    # Just a place holder for our 0th image embedding.
    embeddings = torch.tensor([])
    
    with torch.no_grad():
        for batch_idx, data in enumerate(full_loader):
            
            train_img, lbl = data
            train_img = train_img.to(device)
            
            # Get encoder outputs and move outputs to cpu
            enc_output = model(train_img).cpu()
            # Keep adding these outputs to embeddings.
            embeddings = torch.cat((embeddings, enc_output), 0)

    # Return the embeddings
    return embeddings

# %%
## image와 가장 비슷한 top k개 image의 idx를 뽑음
def compute_similar_images(image, num_images, embedding, device):
    transform = torchvision.transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)), 
        transforms.Resize((224, 224))
    ])
    
    image_tensor = transform(image).to(device)
    image_tensor = image_tensor.unsqueeze(0) # batch dim 늘려줌

    with torch.no_grad():
        image_embedding = model(image_tensor).cpu().detach().numpy() # [1, 512]
        
    flattened_embedding = image_embedding.reshape((image_embedding.shape[0], -1)) # [1, 512]

    knn = NearestNeighbors(n_neighbors=num_images, metric="cosine")
    knn.fit(embedding.reshape((embedding.shape[0], -1)))
    _, indices = knn.kneighbors(flattened_embedding)
    indices_list = indices.tolist()
    return indices_list

# %%
#get embedding of images from full_loader
embedding = create_embedding(model, full_loader, device)

# %%
embedding.shape
# Out:
# torch.Size([11788, 512])

# %%
def imshow(img):
    img = img / 2 + 0.5  # Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()
    
import matplotlib.pyplot as plt
import PIL

##find the most closest image to input_image in the full_dataset
input_image = PIL.Image.open("bird1.jpeg").convert("RGB")
indices_list = compute_similar_images(input_image, 3, embedding, device)
print(indices_list)

for i in indices_list[0]:
    img, _ = full_dataset[i]
    imshow(img)
    import pdb; pdb.set_trace()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[2698, 3178, 2694]]
# > <ipython-input-31-5572e1268c19>(15)<module>()
#      13 print(indices_list)
#      14
# ---> 15 for i in indices_list[0]:
#      16     img, _ = full_dataset[i]
#      17     imshow(img)
# ipdb>  c
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# > <ipython-input-31-5572e1268c19>(15)<module>()
#      13 print(indices_list)
#      14
# ---> 15 for i in indices_list[0]:
#      16     img, _ = full_dataset[i]
#      17     imshow(img)
# ipdb>  c
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# > <ipython-input-31-5572e1268c19>(15)<module>()
#      13 print(indices_list)
#      14
# ---> 15 for i in indices_list[0]:
#      16     img, _ = full_dataset[i]
#      17     imshow(img)
# ipdb>  c
