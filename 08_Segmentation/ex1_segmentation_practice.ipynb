# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import torch.nn as nn
import os
import os.path as osp
import collections
import PIL
import imageio
from distutils.version import LooseVersion
import torch.nn.functional as F
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# # Downloading dataset from google drive, 밑의 코드의 주석을 풀면 구글 드라이브로 부터 데이터셋 다운, 압축이 풀리고, Kitti라는 폴더가 생성됩니다. 

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=19EiycfOQtf6uDKvMgwlHZB50cAxX_U4z' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=19EiycfOQtf6uDKvMgwlHZB50cAxX_U4z" -O Kitti.zip && rm -rf /tmp/cookies.txt
# !mkdir Kitti
# !unzip Kitti.zip -d Kitti
# Out:
# --2022-06-23 01:09:33--  https://docs.google.com/uc?export=download&confirm=t&id=19EiycfOQtf6uDKvMgwlHZB50cAxX_U4z
# Resolving docs.google.com (docs.google.com)... 142.251.42.174, 2404:6800:4004:826::200e
# Connecting to docs.google.com (docs.google.com)|142.251.42.174|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-44-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0c4pjnh4k6rle976rt6flfkf2qa46q2j/1655946525000/05110516000762554458/*/19EiycfOQtf6uDKvMgwlHZB50cAxX_U4z?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2022-06-23 01:09:33--  https://doc-04-44-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0c4pjnh4k6rle976rt6flfkf2qa46q2j/1655946525000/05110516000762554458/*/19EiycfOQtf6uDKvMgwlHZB50cAxX_U4z?e=download
# Resolving doc-04-44-docs.googleusercontent.com (doc-04-44-docs.googleusercontent.com)... 172.217.161.33, 2404:6800:4004:80a::2001
# Connecting to doc-04-44-docs.googleusercontent.com (doc-04-44-docs.googleusercontent.com)|172.217.161.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 471406102 (450M) [application/zip]
# Saving to: ‘Kitti.zip’
#
# Kitti.zip           100%[===================>] 449.57M  11.2MB/s    in 41s
#
# 2022-06-23 01:10:15 (10.9 MB/s) - ‘Kitti.zip’ saved [471406102/471406102]
#
# Archive:  Kitti.zip
#    creating: Kitti/data_road/
#    creating: Kitti/data_road/testing/
#    creating: Kitti/data_road/testing/calib/
#   inflating: Kitti/data_road/testing/calib/um_000000.txt
#   inflating: Kitti/data_road/testing/calib/um_000001.txt
#   inflating: Kitti/data_road/testing/calib/um_000002.txt
#   inflating: Kitti/data_road/testing/calib/um_000003.txt
#   inflating: Kitti/data_road/testing/calib/um_000004.txt
#   inflating: Kitti/data_road/testing/calib/um_000005.txt
#   inflating: Kitti/data_road/testing/calib/um_000006.txt
#   inflating: Kitti/data_road/testing/calib/um_000007.txt
#   inflating: Kitti/data_road/testing/calib/um_000008.txt
#   inflating: Kitti/data_road/testing/calib/um_000009.txt
#   inflating: Kitti/data_road/testing/calib/um_000010.txt
#   inflating: Kitti/data_road/testing/calib/um_000011.txt
#   inflating: Kitti/data_road/testing/calib/um_000012.txt
#   inflating: Kitti/data_road/testing/calib/um_000013.txt
#   inflating: Kitti/data_road/testing/calib/um_000014.txt
#   inflating: Kitti/data_road/testing/calib/um_000015.txt
#   inflating: Kitti/data_road/testing/calib/um_000016.txt
#   inflating: Kitti/data_road/testing/calib/um_000017.txt
#   inflating: Kitti/data_road/testing/calib/um_000018.txt
#   inflating: Kitti/data_road/testing/calib/um_000019.txt
#   inflating: Kitti/data_road/testing/calib/um_000020.txt
#   inflating: Kitti/data_road/testing/calib/um_000021.txt
#   inflating: Kitti/data_road/testing/calib/um_000022.txt
#   inflating: Kitti/data_road/testing/calib/um_000023.txt
#   inflating: Kitti/data_road/testing/calib/um_000024.txt
#   inflating: Kitti/data_road/testing/calib/um_000025.txt
#   inflating: Kitti/data_road/testing/calib/um_000026.txt
#   inflating: Kitti/data_road/testing/calib/um_000027.txt
#   inflating: Kitti/data_road/testing/calib/um_000028.txt
#   inflating: Kitti/data_road/testing/calib/um_000029.txt
#   inflating: Kitti/data_road/testing/calib/um_000030.txt
#   inflating: Kitti/data_road/testing/calib/um_000031.txt
#   inflating: Kitti/data_road/testing/calib/um_000032.txt
#   inflating: Kitti/data_road/testing/calib/um_000033.txt
#   inflating: Kitti/data_road/testing/calib/um_000034.txt
#   inflating: Kitti/data_road/testing/calib/um_000035.txt
#   inflating: Kitti/data_road/testing/calib/um_000036.txt
#   inflating: Kitti/data_road/testing/calib/um_000037.txt
#   inflating: Kitti/data_road/testing/calib/um_000038.txt
#   inflating: Kitti/data_road/testing/calib/um_000039.txt
#   inflating: Kitti/data_road/testing/calib/um_000040.txt
#   inflating: Kitti/data_road/testing/calib/um_000041.txt
#   inflating: Kitti/data_road/testing/calib/um_000042.txt
#   inflating: Kitti/data_road/testing/calib/um_000043.txt
#   inflating: Kitti/data_road/testing/calib/um_000044.txt
#   inflating: Kitti/data_road/testing/calib/um_000045.txt
#   inflating: Kitti/data_road/testing/calib/um_000046.txt
#   inflating: Kitti/data_road/testing/calib/um_000047.txt
#   inflating: Kitti/data_road/testing/calib/um_000048.txt
#   inflating: Kitti/data_road/testing/calib/um_000049.txt
#   inflating: Kitti/data_road/testing/calib/um_000050.txt
#   inflating: Kitti/data_road/testing/calib/um_000051.txt
#   inflating: Kitti/data_road/testing/calib/um_000052.txt
#   inflating: Kitti/data_road/testing/calib/um_000053.txt
#   inflating: Kitti/data_road/testing/calib/um_000054.txt
#   inflating: Kitti/data_road/testing/calib/um_000055.txt
#   inflating: Kitti/data_road/testing/calib/um_000056.txt
#   inflating: Kitti/data_road/testing/calib/um_000057.txt
#   inflating: Kitti/data_road/testing/calib/um_000058.txt
#   inflating: Kitti/data_road/testing/calib/um_000059.txt
#   inflating: Kitti/data_road/testing/calib/um_000060.txt
#   inflating: Kitti/data_road/testing/calib/um_000061.txt
#   inflating: Kitti/data_road/testing/calib/um_000062.txt
#   inflating: Kitti/data_road/testing/calib/um_000063.txt
#   inflating: Kitti/data_road/testing/calib/um_000064.txt
#   inflating: Kitti/data_road/testing/calib/um_000065.txt
#   inflating: Kitti/data_road/testing/calib/um_000066.txt
#   inflating: Kitti/data_road/testing/calib/um_000067.txt
#   inflating: Kitti/data_road/testing/calib/um_000068.txt
#   inflating: Kitti/data_road/testing/calib/um_000069.txt
#   inflating: Kitti/data_road/testing/calib/um_000070.txt
#   inflating: Kitti/data_road/testing/calib/um_000071.txt
#   inflating: Kitti/data_road/testing/calib/um_000072.txt
#   inflating: Kitti/data_road/testing/calib/um_000073.txt
#   inflating: Kitti/data_road/testing/calib/um_000074.txt
#   inflating: Kitti/data_road/testing/calib/um_000075.txt
#   inflating: Kitti/data_road/testing/calib/um_000076.txt
#   inflating: Kitti/data_road/testing/calib/um_000077.txt
#   inflating: Kitti/data_road/testing/calib/um_000078.txt
#   inflating: Kitti/data_road/testing/calib/um_000079.txt
#   inflating: Kitti/data_road/testing/calib/um_000080.txt
#   inflating: Kitti/data_road/testing/calib/um_000081.txt
#   inflating: Kitti/data_road/testing/calib/um_000082.txt
#   inflating: Kitti/data_road/testing/calib/um_000083.txt
#   inflating: Kitti/data_road/testing/calib/um_000084.txt
#   inflating: Kitti/data_road/testing/calib/um_000085.txt
#   inflating: Kitti/data_road/testing/calib/um_000086.txt
#   inflating: Kitti/data_road/testing/calib/um_000087.txt
#   inflating: Kitti/data_road/testing/calib/um_000088.txt
#   inflating: Kitti/data_road/testing/calib/um_000089.txt
#   inflating: Kitti/data_road/testing/calib/um_000090.txt
#   inflating: Kitti/data_road/testing/calib/um_000091.txt
#   inflating: Kitti/data_road/testing/calib/um_000092.txt
#   inflating: Kitti/data_road/testing/calib/um_000093.txt
#   inflating: Kitti/data_road/testing/calib/um_000094.txt
#   inflating: Kitti/data_road/testing/calib/um_000095.txt
#   inflating: Kitti/data_road/testing/calib/umm_000000.txt
#   inflating: Kitti/data_road/testing/calib/umm_000001.txt
#   inflating: Kitti/data_road/testing/calib/umm_000002.txt
#   inflating: Kitti/data_road/testing/calib/umm_000003.txt
#   inflating: Kitti/data_road/testing/calib/umm_000004.txt
#   inflating: Kitti/data_road/testing/calib/umm_000005.txt
#   inflating: Kitti/data_road/testing/calib/umm_000006.txt
#   inflating: Kitti/data_road/testing/calib/umm_000007.txt
#   inflating: Kitti/data_road/testing/calib/umm_000008.txt
#   inflating: Kitti/data_road/testing/calib/umm_000009.txt
#   inflating: Kitti/data_road/testing/calib/umm_000010.txt
#   inflating: Kitti/data_road/testing/calib/umm_000011.txt
#   inflating: Kitti/data_road/testing/calib/umm_000012.txt
#   inflating: Kitti/data_road/testing/calib/umm_000013.txt
#   inflating: Kitti/data_road/testing/calib/umm_000014.txt
#   inflating: Kitti/data_road/testing/calib/umm_000015.txt
#   inflating: Kitti/data_road/testing/calib/umm_000016.txt
#   inflating: Kitti/data_road/testing/calib/umm_000017.txt
#   inflating: Kitti/data_road/testing/calib/umm_000018.txt
#   inflating: Kitti/data_road/testing/calib/umm_000019.txt
#   inflating: Kitti/data_road/testing/calib/umm_000020.txt
#   inflating: Kitti/data_road/testing/calib/umm_000021.txt
#   inflating: Kitti/data_road/testing/calib/umm_000022.txt
#   inflating: Kitti/data_road/testing/calib/umm_000023.txt
#   inflating: Kitti/data_road/testing/calib/umm_000024.txt
#   inflating: Kitti/data_road/testing/calib/umm_000025.txt
#   inflating: Kitti/data_road/testing/calib/umm_000026.txt
#   inflating: Kitti/data_road/testing/calib/umm_000027.txt
#   inflating: Kitti/data_road/testing/calib/umm_000028.txt
#   inflating: Kitti/data_road/testing/calib/umm_000029.txt
#   inflating: Kitti/data_road/testing/calib/umm_000030.txt
#   inflating: Kitti/data_road/testing/calib/umm_000031.txt
#   inflating: Kitti/data_road/testing/calib/umm_000032.txt
#   inflating: Kitti/data_road/testing/calib/umm_000033.txt
#   inflating: Kitti/data_road/testing/calib/umm_000034.txt
#   inflating: Kitti/data_road/testing/calib/umm_000035.txt
#   inflating: Kitti/data_road/testing/calib/umm_000036.txt
#   inflating: Kitti/data_road/testing/calib/umm_000037.txt
#   inflating: Kitti/data_road/testing/calib/umm_000038.txt
#   inflating: Kitti/data_road/testing/calib/umm_000039.txt
#   inflating: Kitti/data_road/testing/calib/umm_000040.txt
#   inflating: Kitti/data_road/testing/calib/umm_000041.txt
#   inflating: Kitti/data_road/testing/calib/umm_000042.txt
#   inflating: Kitti/data_road/testing/calib/umm_000043.txt
#   inflating: Kitti/data_road/testing/calib/umm_000044.txt
#   inflating: Kitti/data_road/testing/calib/umm_000045.txt
#   inflating: Kitti/data_road/testing/calib/umm_000046.txt
#   inflating: Kitti/data_road/testing/calib/umm_000047.txt
#   inflating: Kitti/data_road/testing/calib/umm_000048.txt
#   inflating: Kitti/data_road/testing/calib/umm_000049.txt
#   inflating: Kitti/data_road/testing/calib/umm_000050.txt
#   inflating: Kitti/data_road/testing/calib/umm_000051.txt
#   inflating: Kitti/data_road/testing/calib/umm_000052.txt
#   inflating: Kitti/data_road/testing/calib/umm_000053.txt
#   inflating: Kitti/data_road/testing/calib/umm_000054.txt
#   inflating: Kitti/data_road/testing/calib/umm_000055.txt
#   inflating: Kitti/data_road/testing/calib/umm_000056.txt
#   inflating: Kitti/data_road/testing/calib/umm_000057.txt
#   inflating: Kitti/data_road/testing/calib/umm_000058.txt
#   inflating: Kitti/data_road/testing/calib/umm_000059.txt
#   inflating: Kitti/data_road/testing/calib/umm_000060.txt
#   inflating: Kitti/data_road/testing/calib/umm_000061.txt
#   inflating: Kitti/data_road/testing/calib/umm_000062.txt
#   inflating: Kitti/data_road/testing/calib/umm_000063.txt
#   inflating: Kitti/data_road/testing/calib/umm_000064.txt
#   inflating: Kitti/data_road/testing/calib/umm_000065.txt
#   inflating: Kitti/data_road/testing/calib/umm_000066.txt
#   inflating: Kitti/data_road/testing/calib/umm_000067.txt
#   inflating: Kitti/data_road/testing/calib/umm_000068.txt
#   inflating: Kitti/data_road/testing/calib/umm_000069.txt
#   inflating: Kitti/data_road/testing/calib/umm_000070.txt
#   inflating: Kitti/data_road/testing/calib/umm_000071.txt
#   inflating: Kitti/data_road/testing/calib/umm_000072.txt
#   inflating: Kitti/data_road/testing/calib/umm_000073.txt
#   inflating: Kitti/data_road/testing/calib/umm_000074.txt
#   inflating: Kitti/data_road/testing/calib/umm_000075.txt
#   inflating: Kitti/data_road/testing/calib/umm_000076.txt
#   inflating: Kitti/data_road/testing/calib/umm_000077.txt
#   inflating: Kitti/data_road/testing/calib/umm_000078.txt
#   inflating: Kitti/data_road/testing/calib/umm_000079.txt
#   inflating: Kitti/data_road/testing/calib/umm_000080.txt
#   inflating: Kitti/data_road/testing/calib/umm_000081.txt
#   inflating: Kitti/data_road/testing/calib/umm_000082.txt
#   inflating: Kitti/data_road/testing/calib/umm_000083.txt
#   inflating: Kitti/data_road/testing/calib/umm_000084.txt
#   inflating: Kitti/data_road/testing/calib/umm_000085.txt
#   inflating: Kitti/data_road/testing/calib/umm_000086.txt
#   inflating: Kitti/data_road/testing/calib/umm_000087.txt
#   inflating: Kitti/data_road/testing/calib/umm_000088.txt
#   inflating: Kitti/data_road/testing/calib/umm_000089.txt
#   inflating: Kitti/data_road/testing/calib/umm_000090.txt
#   inflating: Kitti/data_road/testing/calib/umm_000091.txt
#   inflating: Kitti/data_road/testing/calib/umm_000092.txt
#   inflating: Kitti/data_road/testing/calib/umm_000093.txt
#   inflating: Kitti/data_road/testing/calib/uu_000000.txt
#   inflating: Kitti/data_road/testing/calib/uu_000001.txt
#   inflating: Kitti/data_road/testing/calib/uu_000002.txt
#   inflating: Kitti/data_road/testing/calib/uu_000003.txt
#   inflating: Kitti/data_road/testing/calib/uu_000004.txt
#   inflating: Kitti/data_road/testing/calib/uu_000005.txt
#   inflating: Kitti/data_road/testing/calib/uu_000006.txt
#   inflating: Kitti/data_road/testing/calib/uu_000007.txt
#   inflating: Kitti/data_road/testing/calib/uu_000008.txt
#   inflating: Kitti/data_road/testing/calib/uu_000009.txt
#   inflating: Kitti/data_road/testing/calib/uu_000010.txt
#   inflating: Kitti/data_road/testing/calib/uu_000011.txt
#   inflating: Kitti/data_road/testing/calib/uu_000012.txt
#   inflating: Kitti/data_road/testing/calib/uu_000013.txt
#   inflating: Kitti/data_road/testing/calib/uu_000014.txt
#   inflating: Kitti/data_road/testing/calib/uu_000015.txt
#   inflating: Kitti/data_road/testing/calib/uu_000016.txt
#   inflating: Kitti/data_road/testing/calib/uu_000017.txt
#   inflating: Kitti/data_road/testing/calib/uu_000018.txt
#   inflating: Kitti/data_road/testing/calib/uu_000019.txt
#   inflating: Kitti/data_road/testing/calib/uu_000020.txt
#   inflating: Kitti/data_road/testing/calib/uu_000021.txt
#   inflating: Kitti/data_road/testing/calib/uu_000022.txt
#   inflating: Kitti/data_road/testing/calib/uu_000023.txt
#   inflating: Kitti/data_road/testing/calib/uu_000024.txt
#   inflating: Kitti/data_road/testing/calib/uu_000025.txt
#   inflating: Kitti/data_road/testing/calib/uu_000026.txt
#   inflating: Kitti/data_road/testing/calib/uu_000027.txt
#   inflating: Kitti/data_road/testing/calib/uu_000028.txt
#   inflating: Kitti/data_road/testing/calib/uu_000029.txt
#   inflating: Kitti/data_road/testing/calib/uu_000030.txt
#   inflating: Kitti/data_road/testing/calib/uu_000031.txt
#   inflating: Kitti/data_road/testing/calib/uu_000032.txt
#   inflating: Kitti/data_road/testing/calib/uu_000033.txt
#   inflating: Kitti/data_road/testing/calib/uu_000034.txt
#   inflating: Kitti/data_road/testing/calib/uu_000035.txt
#   inflating: Kitti/data_road/testing/calib/uu_000036.txt
#   inflating: Kitti/data_road/testing/calib/uu_000037.txt
#   inflating: Kitti/data_road/testing/calib/uu_000038.txt
#   inflating: Kitti/data_road/testing/calib/uu_000039.txt
#   inflating: Kitti/data_road/testing/calib/uu_000040.txt
#   inflating: Kitti/data_road/testing/calib/uu_000041.txt
#   inflating: Kitti/data_road/testing/calib/uu_000042.txt
#   inflating: Kitti/data_road/testing/calib/uu_000043.txt
#   inflating: Kitti/data_road/testing/calib/uu_000044.txt
#   inflating: Kitti/data_road/testing/calib/uu_000045.txt
#   inflating: Kitti/data_road/testing/calib/uu_000046.txt
#   inflating: Kitti/data_road/testing/calib/uu_000047.txt
#   inflating: Kitti/data_road/testing/calib/uu_000048.txt
#   inflating: Kitti/data_road/testing/calib/uu_000049.txt
#   inflating: Kitti/data_road/testing/calib/uu_000050.txt
#   inflating: Kitti/data_road/testing/calib/uu_000051.txt
#   inflating: Kitti/data_road/testing/calib/uu_000052.txt
#   inflating: Kitti/data_road/testing/calib/uu_000053.txt
#   inflating: Kitti/data_road/testing/calib/uu_000054.txt
#   inflating: Kitti/data_road/testing/calib/uu_000055.txt
#   inflating: Kitti/data_road/testing/calib/uu_000056.txt
#   inflating: Kitti/data_road/testing/calib/uu_000057.txt
#   inflating: Kitti/data_road/testing/calib/uu_000058.txt
#   inflating: Kitti/data_road/testing/calib/uu_000059.txt
#   inflating: Kitti/data_road/testing/calib/uu_000060.txt
#   inflating: Kitti/data_road/testing/calib/uu_000061.txt
#   inflating: Kitti/data_road/testing/calib/uu_000062.txt
#   inflating: Kitti/data_road/testing/calib/uu_000063.txt
#   inflating: Kitti/data_road/testing/calib/uu_000064.txt
#   inflating: Kitti/data_road/testing/calib/uu_000065.txt
#   inflating: Kitti/data_road/testing/calib/uu_000066.txt
#   inflating: Kitti/data_road/testing/calib/uu_000067.txt
#   inflating: Kitti/data_road/testing/calib/uu_000068.txt
#   inflating: Kitti/data_road/testing/calib/uu_000069.txt
#   inflating: Kitti/data_road/testing/calib/uu_000070.txt
#   inflating: Kitti/data_road/testing/calib/uu_000071.txt
#   inflating: Kitti/data_road/testing/calib/uu_000072.txt
#   inflating: Kitti/data_road/testing/calib/uu_000073.txt
#   inflating: Kitti/data_road/testing/calib/uu_000074.txt
#   inflating: Kitti/data_road/testing/calib/uu_000075.txt
#   inflating: Kitti/data_road/testing/calib/uu_000076.txt
#   inflating: Kitti/data_road/testing/calib/uu_000077.txt
#   inflating: Kitti/data_road/testing/calib/uu_000078.txt
#   inflating: Kitti/data_road/testing/calib/uu_000079.txt
#   inflating: Kitti/data_road/testing/calib/uu_000080.txt
#   inflating: Kitti/data_road/testing/calib/uu_000081.txt
#   inflating: Kitti/data_road/testing/calib/uu_000082.txt
#   inflating: Kitti/data_road/testing/calib/uu_000083.txt
#   inflating: Kitti/data_road/testing/calib/uu_000084.txt
#   inflating: Kitti/data_road/testing/calib/uu_000085.txt
#   inflating: Kitti/data_road/testing/calib/uu_000086.txt
#   inflating: Kitti/data_road/testing/calib/uu_000087.txt
#   inflating: Kitti/data_road/testing/calib/uu_000088.txt
#   inflating: Kitti/data_road/testing/calib/uu_000089.txt
#   inflating: Kitti/data_road/testing/calib/uu_000090.txt
#   inflating: Kitti/data_road/testing/calib/uu_000091.txt
#   inflating: Kitti/data_road/testing/calib/uu_000092.txt
#   inflating: Kitti/data_road/testing/calib/uu_000093.txt
#   inflating: Kitti/data_road/testing/calib/uu_000094.txt
#   inflating: Kitti/data_road/testing/calib/uu_000095.txt
#   inflating: Kitti/data_road/testing/calib/uu_000096.txt
#   inflating: Kitti/data_road/testing/calib/uu_000097.txt
#   inflating: Kitti/data_road/testing/calib/uu_000098.txt
#   inflating: Kitti/data_road/testing/calib/uu_000099.txt
#    creating: Kitti/data_road/testing/image_2/
#   inflating: Kitti/data_road/testing/image_2/um_000000.png
#   inflating: Kitti/data_road/testing/image_2/um_000001.png
#   inflating: Kitti/data_road/testing/image_2/um_000002.png
#   inflating: Kitti/data_road/testing/image_2/um_000003.png
#   inflating: Kitti/data_road/testing/image_2/um_000004.png
#   inflating: Kitti/data_road/testing/image_2/um_000005.png
#   inflating: Kitti/data_road/testing/image_2/um_000006.png
#   inflating: Kitti/data_road/testing/image_2/um_000007.png
#   inflating: Kitti/data_road/testing/image_2/um_000008.png
#   inflating: Kitti/data_road/testing/image_2/um_000009.png
#   inflating: Kitti/data_road/testing/image_2/um_000010.png
#   inflating: Kitti/data_road/testing/image_2/um_000011.png
#   inflating: Kitti/data_road/testing/image_2/um_000012.png
#   inflating: Kitti/data_road/testing/image_2/um_000013.png
#   inflating: Kitti/data_road/testing/image_2/um_000014.png
#   inflating: Kitti/data_road/testing/image_2/um_000015.png
#   inflating: Kitti/data_road/testing/image_2/um_000016.png
#   inflating: Kitti/data_road/testing/image_2/um_000017.png
#   inflating: Kitti/data_road/testing/image_2/um_000018.png
#   inflating: Kitti/data_road/testing/image_2/um_000019.png
#   inflating: Kitti/data_road/testing/image_2/um_000020.png
#   inflating: Kitti/data_road/testing/image_2/um_000021.png
#   inflating: Kitti/data_road/testing/image_2/um_000022.png
#   inflating: Kitti/data_road/testing/image_2/um_000023.png
#   inflating: Kitti/data_road/testing/image_2/um_000024.png
#   inflating: Kitti/data_road/testing/image_2/um_000025.png
#   inflating: Kitti/data_road/testing/image_2/um_000026.png
#   inflating: Kitti/data_road/testing/image_2/um_000027.png
#   inflating: Kitti/data_road/testing/image_2/um_000028.png
#   inflating: Kitti/data_road/testing/image_2/um_000029.png
#   inflating: Kitti/data_road/testing/image_2/um_000030.png
#   inflating: Kitti/data_road/testing/image_2/um_000031.png
#   inflating: Kitti/data_road/testing/image_2/um_000032.png
#   inflating: Kitti/data_road/testing/image_2/um_000033.png
#   inflating: Kitti/data_road/testing/image_2/um_000034.png
#   inflating: Kitti/data_road/testing/image_2/um_000035.png
#   inflating: Kitti/data_road/testing/image_2/um_000036.png
#   inflating: Kitti/data_road/testing/image_2/um_000037.png
#   inflating: Kitti/data_road/testing/image_2/um_000038.png
#   inflating: Kitti/data_road/testing/image_2/um_000039.png
#   inflating: Kitti/data_road/testing/image_2/um_000040.png
#   inflating: Kitti/data_road/testing/image_2/um_000041.png
#   inflating: Kitti/data_road/testing/image_2/um_000042.png
#   inflating: Kitti/data_road/testing/image_2/um_000043.png
#   inflating: Kitti/data_road/testing/image_2/um_000044.png
#   inflating: Kitti/data_road/testing/image_2/um_000045.png
#   inflating: Kitti/data_road/testing/image_2/um_000046.png
#   inflating: Kitti/data_road/testing/image_2/um_000047.png
#   inflating: Kitti/data_road/testing/image_2/um_000048.png
#   inflating: Kitti/data_road/testing/image_2/um_000049.png
#   inflating: Kitti/data_road/testing/image_2/um_000050.png
#   inflating: Kitti/data_road/testing/image_2/um_000051.png
#   inflating: Kitti/data_road/testing/image_2/um_000052.png
#   inflating: Kitti/data_road/testing/image_2/um_000053.png
#   inflating: Kitti/data_road/testing/image_2/um_000054.png
#   inflating: Kitti/data_road/testing/image_2/um_000055.png
#   inflating: Kitti/data_road/testing/image_2/um_000056.png
#   inflating: Kitti/data_road/testing/image_2/um_000057.png
#   inflating: Kitti/data_road/testing/image_2/um_000058.png
#   inflating: Kitti/data_road/testing/image_2/um_000059.png
#   inflating: Kitti/data_road/testing/image_2/um_000060.png
#   inflating: Kitti/data_road/testing/image_2/um_000061.png
#   inflating: Kitti/data_road/testing/image_2/um_000062.png
#   inflating: Kitti/data_road/testing/image_2/um_000063.png
#   inflating: Kitti/data_road/testing/image_2/um_000064.png
#   inflating: Kitti/data_road/testing/image_2/um_000065.png
#   inflating: Kitti/data_road/testing/image_2/um_000066.png
#   inflating: Kitti/data_road/testing/image_2/um_000067.png
#   inflating: Kitti/data_road/testing/image_2/um_000068.png
#   inflating: Kitti/data_road/testing/image_2/um_000069.png
#   inflating: Kitti/data_road/testing/image_2/um_000070.png
#   inflating: Kitti/data_road/testing/image_2/um_000071.png
#   inflating: Kitti/data_road/testing/image_2/um_000072.png
#   inflating: Kitti/data_road/testing/image_2/um_000073.png
#   inflating: Kitti/data_road/testing/image_2/um_000074.png
#   inflating: Kitti/data_road/testing/image_2/um_000075.png
#   inflating: Kitti/data_road/testing/image_2/um_000076.png
#   inflating: Kitti/data_road/testing/image_2/um_000077.png
#   inflating: Kitti/data_road/testing/image_2/um_000078.png
#   inflating: Kitti/data_road/testing/image_2/um_000079.png
#   inflating: Kitti/data_road/testing/image_2/um_000080.png
#   inflating: Kitti/data_road/testing/image_2/um_000081.png
#   inflating: Kitti/data_road/testing/image_2/um_000082.png
#   inflating: Kitti/data_road/testing/image_2/um_000083.png
#   inflating: Kitti/data_road/testing/image_2/um_000084.png
#   inflating: Kitti/data_road/testing/image_2/um_000085.png
#   inflating: Kitti/data_road/testing/image_2/um_000086.png
#   inflating: Kitti/data_road/testing/image_2/um_000087.png
#   inflating: Kitti/data_road/testing/image_2/um_000088.png
#   inflating: Kitti/data_road/testing/image_2/um_000089.png
#   inflating: Kitti/data_road/testing/image_2/um_000090.png
#   inflating: Kitti/data_road/testing/image_2/um_000091.png
#   inflating: Kitti/data_road/testing/image_2/um_000092.png
#   inflating: Kitti/data_road/testing/image_2/um_000093.png
#   inflating: Kitti/data_road/testing/image_2/um_000094.png
#   inflating: Kitti/data_road/testing/image_2/um_000095.png
#   inflating: Kitti/data_road/testing/image_2/umm_000000.png
#   inflating: Kitti/data_road/testing/image_2/umm_000001.png
#   inflating: Kitti/data_road/testing/image_2/umm_000002.png
#   inflating: Kitti/data_road/testing/image_2/umm_000003.png
#   inflating: Kitti/data_road/testing/image_2/umm_000004.png
#   inflating: Kitti/data_road/testing/image_2/umm_000005.png
#   inflating: Kitti/data_road/testing/image_2/umm_000006.png
#   inflating: Kitti/data_road/testing/image_2/umm_000007.png
#   inflating: Kitti/data_road/testing/image_2/umm_000008.png
#   inflating: Kitti/data_road/testing/image_2/umm_000009.png
#   inflating: Kitti/data_road/testing/image_2/umm_000010.png
#   inflating: Kitti/data_road/testing/image_2/umm_000011.png
#   inflating: Kitti/data_road/testing/image_2/umm_000012.png
#   inflating: Kitti/data_road/testing/image_2/umm_000013.png
#   inflating: Kitti/data_road/testing/image_2/umm_000014.png
#   inflating: Kitti/data_road/testing/image_2/umm_000015.png
#   inflating: Kitti/data_road/testing/image_2/umm_000016.png
#   inflating: Kitti/data_road/testing/image_2/umm_000017.png
#   inflating: Kitti/data_road/testing/image_2/umm_000018.png
#   inflating: Kitti/data_road/testing/image_2/umm_000019.png
#   inflating: Kitti/data_road/testing/image_2/umm_000020.png
#   inflating: Kitti/data_road/testing/image_2/umm_000021.png
#   inflating: Kitti/data_road/testing/image_2/umm_000022.png
#   inflating: Kitti/data_road/testing/image_2/umm_000023.png
#   inflating: Kitti/data_road/testing/image_2/umm_000024.png
#   inflating: Kitti/data_road/testing/image_2/umm_000025.png
#   inflating: Kitti/data_road/testing/image_2/umm_000026.png
#   inflating: Kitti/data_road/testing/image_2/umm_000027.png
#   inflating: Kitti/data_road/testing/image_2/umm_000028.png
#   inflating: Kitti/data_road/testing/image_2/umm_000029.png
#   inflating: Kitti/data_road/testing/image_2/umm_000030.png
#   inflating: Kitti/data_road/testing/image_2/umm_000031.png
#   inflating: Kitti/data_road/testing/image_2/umm_000032.png
#   inflating: Kitti/data_road/testing/image_2/umm_000033.png
#   inflating: Kitti/data_road/testing/image_2/umm_000034.png
#   inflating: Kitti/data_road/testing/image_2/umm_000035.png
#   inflating: Kitti/data_road/testing/image_2/umm_000036.png
#   inflating: Kitti/data_road/testing/image_2/umm_000037.png
#   inflating: Kitti/data_road/testing/image_2/umm_000038.png
#   inflating: Kitti/data_road/testing/image_2/umm_000039.png
#   inflating: Kitti/data_road/testing/image_2/umm_000040.png
#   inflating: Kitti/data_road/testing/image_2/umm_000041.png
#   inflating: Kitti/data_road/testing/image_2/umm_000042.png
#   inflating: Kitti/data_road/testing/image_2/umm_000043.png
#   inflating: Kitti/data_road/testing/image_2/umm_000044.png
#   inflating: Kitti/data_road/testing/image_2/umm_000045.png
#   inflating: Kitti/data_road/testing/image_2/umm_000046.png
#   inflating: Kitti/data_road/testing/image_2/umm_000047.png
#   inflating: Kitti/data_road/testing/image_2/umm_000048.png
#   inflating: Kitti/data_road/testing/image_2/umm_000049.png
#   inflating: Kitti/data_road/testing/image_2/umm_000050.png
#   inflating: Kitti/data_road/testing/image_2/umm_000051.png
#   inflating: Kitti/data_road/testing/image_2/umm_000052.png
#   inflating: Kitti/data_road/testing/image_2/umm_000053.png
#   inflating: Kitti/data_road/testing/image_2/umm_000054.png
#   inflating: Kitti/data_road/testing/image_2/umm_000055.png
#   inflating: Kitti/data_road/testing/image_2/umm_000056.png
#   inflating: Kitti/data_road/testing/image_2/umm_000057.png
#   inflating: Kitti/data_road/testing/image_2/umm_000058.png
#   inflating: Kitti/data_road/testing/image_2/umm_000059.png
#   inflating: Kitti/data_road/testing/image_2/umm_000060.png
#   inflating: Kitti/data_road/testing/image_2/umm_000061.png
#   inflating: Kitti/data_road/testing/image_2/umm_000062.png
#   inflating: Kitti/data_road/testing/image_2/umm_000063.png
#   inflating: Kitti/data_road/testing/image_2/umm_000064.png
#   inflating: Kitti/data_road/testing/image_2/umm_000065.png
#   inflating: Kitti/data_road/testing/image_2/umm_000066.png
#   inflating: Kitti/data_road/testing/image_2/umm_000067.png
#   inflating: Kitti/data_road/testing/image_2/umm_000068.png
#   inflating: Kitti/data_road/testing/image_2/umm_000069.png
#   inflating: Kitti/data_road/testing/image_2/umm_000070.png
#   inflating: Kitti/data_road/testing/image_2/umm_000071.png
#   inflating: Kitti/data_road/testing/image_2/umm_000072.png
#   inflating: Kitti/data_road/testing/image_2/umm_000073.png
#   inflating: Kitti/data_road/testing/image_2/umm_000074.png
#   inflating: Kitti/data_road/testing/image_2/umm_000075.png
#   inflating: Kitti/data_road/testing/image_2/umm_000076.png
#   inflating: Kitti/data_road/testing/image_2/umm_000077.png
#   inflating: Kitti/data_road/testing/image_2/umm_000078.png
#   inflating: Kitti/data_road/testing/image_2/umm_000079.png
#   inflating: Kitti/data_road/testing/image_2/umm_000080.png
#   inflating: Kitti/data_road/testing/image_2/umm_000081.png
#   inflating: Kitti/data_road/testing/image_2/umm_000082.png
#   inflating: Kitti/data_road/testing/image_2/umm_000083.png
#   inflating: Kitti/data_road/testing/image_2/umm_000084.png
#   inflating: Kitti/data_road/testing/image_2/umm_000085.png
#   inflating: Kitti/data_road/testing/image_2/umm_000086.png
#   inflating: Kitti/data_road/testing/image_2/umm_000087.png
#   inflating: Kitti/data_road/testing/image_2/umm_000088.png
#   inflating: Kitti/data_road/testing/image_2/umm_000089.png
#   inflating: Kitti/data_road/testing/image_2/umm_000090.png
#   inflating: Kitti/data_road/testing/image_2/umm_000091.png
#   inflating: Kitti/data_road/testing/image_2/umm_000092.png
#   inflating: Kitti/data_road/testing/image_2/umm_000093.png
#   inflating: Kitti/data_road/testing/image_2/uu_000000.png
#   inflating: Kitti/data_road/testing/image_2/uu_000001.png
#   inflating: Kitti/data_road/testing/image_2/uu_000002.png
#   inflating: Kitti/data_road/testing/image_2/uu_000003.png
#   inflating: Kitti/data_road/testing/image_2/uu_000004.png
#   inflating: Kitti/data_road/testing/image_2/uu_000005.png
#   inflating: Kitti/data_road/testing/image_2/uu_000006.png
#   inflating: Kitti/data_road/testing/image_2/uu_000007.png
#   inflating: Kitti/data_road/testing/image_2/uu_000008.png
#   inflating: Kitti/data_road/testing/image_2/uu_000009.png
#   inflating: Kitti/data_road/testing/image_2/uu_000010.png
#   inflating: Kitti/data_road/testing/image_2/uu_000011.png
#   inflating: Kitti/data_road/testing/image_2/uu_000012.png
#   inflating: Kitti/data_road/testing/image_2/uu_000013.png
#   inflating: Kitti/data_road/testing/image_2/uu_000014.png
#   inflating: Kitti/data_road/testing/image_2/uu_000015.png
#   inflating: Kitti/data_road/testing/image_2/uu_000016.png
#   inflating: Kitti/data_road/testing/image_2/uu_000017.png
#   inflating: Kitti/data_road/testing/image_2/uu_000018.png
#   inflating: Kitti/data_road/testing/image_2/uu_000019.png
#   inflating: Kitti/data_road/testing/image_2/uu_000020.png
#   inflating: Kitti/data_road/testing/image_2/uu_000021.png
#   inflating: Kitti/data_road/testing/image_2/uu_000022.png
#   inflating: Kitti/data_road/testing/image_2/uu_000023.png
#   inflating: Kitti/data_road/testing/image_2/uu_000024.png
#   inflating: Kitti/data_road/testing/image_2/uu_000025.png
#   inflating: Kitti/data_road/testing/image_2/uu_000026.png
#   inflating: Kitti/data_road/testing/image_2/uu_000027.png
#   inflating: Kitti/data_road/testing/image_2/uu_000028.png
#   inflating: Kitti/data_road/testing/image_2/uu_000029.png
#   inflating: Kitti/data_road/testing/image_2/uu_000030.png
#   inflating: Kitti/data_road/testing/image_2/uu_000031.png
#   inflating: Kitti/data_road/testing/image_2/uu_000032.png
#   inflating: Kitti/data_road/testing/image_2/uu_000033.png
#   inflating: Kitti/data_road/testing/image_2/uu_000034.png
#   inflating: Kitti/data_road/testing/image_2/uu_000035.png
#   inflating: Kitti/data_road/testing/image_2/uu_000036.png
#   inflating: Kitti/data_road/testing/image_2/uu_000037.png
#   inflating: Kitti/data_road/testing/image_2/uu_000038.png
#   inflating: Kitti/data_road/testing/image_2/uu_000039.png
#   inflating: Kitti/data_road/testing/image_2/uu_000040.png
#   inflating: Kitti/data_road/testing/image_2/uu_000041.png
#   inflating: Kitti/data_road/testing/image_2/uu_000042.png
#   inflating: Kitti/data_road/testing/image_2/uu_000043.png
#   inflating: Kitti/data_road/testing/image_2/uu_000044.png
#   inflating: Kitti/data_road/testing/image_2/uu_000045.png
#   inflating: Kitti/data_road/testing/image_2/uu_000046.png
#   inflating: Kitti/data_road/testing/image_2/uu_000047.png
#   inflating: Kitti/data_road/testing/image_2/uu_000048.png
#   inflating: Kitti/data_road/testing/image_2/uu_000049.png
#   inflating: Kitti/data_road/testing/image_2/uu_000050.png
#   inflating: Kitti/data_road/testing/image_2/uu_000051.png
#   inflating: Kitti/data_road/testing/image_2/uu_000052.png
#   inflating: Kitti/data_road/testing/image_2/uu_000053.png
#   inflating: Kitti/data_road/testing/image_2/uu_000054.png
#   inflating: Kitti/data_road/testing/image_2/uu_000055.png
#   inflating: Kitti/data_road/testing/image_2/uu_000056.png
#   inflating: Kitti/data_road/testing/image_2/uu_000057.png
#   inflating: Kitti/data_road/testing/image_2/uu_000058.png
#   inflating: Kitti/data_road/testing/image_2/uu_000059.png
#   inflating: Kitti/data_road/testing/image_2/uu_000060.png
#   inflating: Kitti/data_road/testing/image_2/uu_000061.png
#   inflating: Kitti/data_road/testing/image_2/uu_000062.png
#   inflating: Kitti/data_road/testing/image_2/uu_000063.png
#   inflating: Kitti/data_road/testing/image_2/uu_000064.png
#   inflating: Kitti/data_road/testing/image_2/uu_000065.png
#   inflating: Kitti/data_road/testing/image_2/uu_000066.png
#   inflating: Kitti/data_road/testing/image_2/uu_000067.png
#   inflating: Kitti/data_road/testing/image_2/uu_000068.png
#   inflating: Kitti/data_road/testing/image_2/uu_000069.png
#   inflating: Kitti/data_road/testing/image_2/uu_000070.png
#   inflating: Kitti/data_road/testing/image_2/uu_000071.png
#   inflating: Kitti/data_road/testing/image_2/uu_000072.png
#   inflating: Kitti/data_road/testing/image_2/uu_000073.png
#   inflating: Kitti/data_road/testing/image_2/uu_000074.png
#   inflating: Kitti/data_road/testing/image_2/uu_000075.png
#   inflating: Kitti/data_road/testing/image_2/uu_000076.png
#   inflating: Kitti/data_road/testing/image_2/uu_000077.png
#   inflating: Kitti/data_road/testing/image_2/uu_000078.png
#   inflating: Kitti/data_road/testing/image_2/uu_000079.png
#   inflating: Kitti/data_road/testing/image_2/uu_000080.png
#   inflating: Kitti/data_road/testing/image_2/uu_000081.png
#   inflating: Kitti/data_road/testing/image_2/uu_000082.png
#   inflating: Kitti/data_road/testing/image_2/uu_000083.png
#   inflating: Kitti/data_road/testing/image_2/uu_000084.png
#   inflating: Kitti/data_road/testing/image_2/uu_000085.png
#   inflating: Kitti/data_road/testing/image_2/uu_000086.png
#   inflating: Kitti/data_road/testing/image_2/uu_000087.png
#   inflating: Kitti/data_road/testing/image_2/uu_000088.png
#   inflating: Kitti/data_road/testing/image_2/uu_000089.png
#   inflating: Kitti/data_road/testing/image_2/uu_000090.png
#   inflating: Kitti/data_road/testing/image_2/uu_000091.png
#   inflating: Kitti/data_road/testing/image_2/uu_000092.png
#   inflating: Kitti/data_road/testing/image_2/uu_000093.png
#   inflating: Kitti/data_road/testing/image_2/uu_000094.png
#   inflating: Kitti/data_road/testing/image_2/uu_000095.png
#   inflating: Kitti/data_road/testing/image_2/uu_000096.png
#   inflating: Kitti/data_road/testing/image_2/uu_000097.png
#   inflating: Kitti/data_road/testing/image_2/uu_000098.png
#   inflating: Kitti/data_road/testing/image_2/uu_000099.png
#    creating: Kitti/data_road/training/
#    creating: Kitti/data_road/training/calib/
#   inflating: Kitti/data_road/training/calib/um_000000.txt
#   inflating: Kitti/data_road/training/calib/um_000001.txt
#   inflating: Kitti/data_road/training/calib/um_000002.txt
#   inflating: Kitti/data_road/training/calib/um_000003.txt
#   inflating: Kitti/data_road/training/calib/um_000004.txt
#   inflating: Kitti/data_road/training/calib/um_000005.txt
#   inflating: Kitti/data_road/training/calib/um_000006.txt
#   inflating: Kitti/data_road/training/calib/um_000007.txt
#   inflating: Kitti/data_road/training/calib/um_000008.txt
#   inflating: Kitti/data_road/training/calib/um_000009.txt
#   inflating: Kitti/data_road/training/calib/um_000010.txt
#   inflating: Kitti/data_road/training/calib/um_000011.txt
#   inflating: Kitti/data_road/training/calib/um_000012.txt
#   inflating: Kitti/data_road/training/calib/um_000013.txt
#   inflating: Kitti/data_road/training/calib/um_000014.txt
#   inflating: Kitti/data_road/training/calib/um_000015.txt
#   inflating: Kitti/data_road/training/calib/um_000016.txt
#   inflating: Kitti/data_road/training/calib/um_000017.txt
#   inflating: Kitti/data_road/training/calib/um_000018.txt
#   inflating: Kitti/data_road/training/calib/um_000019.txt
#   inflating: Kitti/data_road/training/calib/um_000020.txt
#   inflating: Kitti/data_road/training/calib/um_000021.txt
#   inflating: Kitti/data_road/training/calib/um_000022.txt
#   inflating: Kitti/data_road/training/calib/um_000023.txt
#   inflating: Kitti/data_road/training/calib/um_000024.txt
#   inflating: Kitti/data_road/training/calib/um_000025.txt
#   inflating: Kitti/data_road/training/calib/um_000026.txt
#   inflating: Kitti/data_road/training/calib/um_000027.txt
#   inflating: Kitti/data_road/training/calib/um_000028.txt
#   inflating: Kitti/data_road/training/calib/um_000029.txt
#   inflating: Kitti/data_road/training/calib/um_000030.txt
#   inflating: Kitti/data_road/training/calib/um_000031.txt
#   inflating: Kitti/data_road/training/calib/um_000032.txt
#   inflating: Kitti/data_road/training/calib/um_000033.txt
#   inflating: Kitti/data_road/training/calib/um_000034.txt
#   inflating: Kitti/data_road/training/calib/um_000035.txt
#   inflating: Kitti/data_road/training/calib/um_000036.txt
#   inflating: Kitti/data_road/training/calib/um_000037.txt
#   inflating: Kitti/data_road/training/calib/um_000038.txt
#   inflating: Kitti/data_road/training/calib/um_000039.txt
#   inflating: Kitti/data_road/training/calib/um_000040.txt
#   inflating: Kitti/data_road/training/calib/um_000041.txt
#   inflating: Kitti/data_road/training/calib/um_000042.txt
#   inflating: Kitti/data_road/training/calib/um_000043.txt
#   inflating: Kitti/data_road/training/calib/um_000044.txt
#   inflating: Kitti/data_road/training/calib/um_000045.txt
#   inflating: Kitti/data_road/training/calib/um_000046.txt
#   inflating: Kitti/data_road/training/calib/um_000047.txt
#   inflating: Kitti/data_road/training/calib/um_000048.txt
#   inflating: Kitti/data_road/training/calib/um_000049.txt
#   inflating: Kitti/data_road/training/calib/um_000050.txt
#   inflating: Kitti/data_road/training/calib/um_000051.txt
#   inflating: Kitti/data_road/training/calib/um_000052.txt
#   inflating: Kitti/data_road/training/calib/um_000053.txt
#   inflating: Kitti/data_road/training/calib/um_000054.txt
#   inflating: Kitti/data_road/training/calib/um_000055.txt
#   inflating: Kitti/data_road/training/calib/um_000056.txt
#   inflating: Kitti/data_road/training/calib/um_000057.txt
#   inflating: Kitti/data_road/training/calib/um_000058.txt
#   inflating: Kitti/data_road/training/calib/um_000059.txt
#   inflating: Kitti/data_road/training/calib/um_000060.txt
#   inflating: Kitti/data_road/training/calib/um_000061.txt
#   inflating: Kitti/data_road/training/calib/um_000062.txt
#   inflating: Kitti/data_road/training/calib/um_000063.txt
#   inflating: Kitti/data_road/training/calib/um_000064.txt
#   inflating: Kitti/data_road/training/calib/um_000065.txt
#   inflating: Kitti/data_road/training/calib/um_000066.txt
#   inflating: Kitti/data_road/training/calib/um_000067.txt
#   inflating: Kitti/data_road/training/calib/um_000068.txt
#   inflating: Kitti/data_road/training/calib/um_000069.txt
#   inflating: Kitti/data_road/training/calib/um_000070.txt
#   inflating: Kitti/data_road/training/calib/um_000071.txt
#   inflating: Kitti/data_road/training/calib/um_000072.txt
#   inflating: Kitti/data_road/training/calib/um_000073.txt
#   inflating: Kitti/data_road/training/calib/um_000074.txt
#   inflating: Kitti/data_road/training/calib/um_000075.txt
#   inflating: Kitti/data_road/training/calib/um_000076.txt
#   inflating: Kitti/data_road/training/calib/um_000077.txt
#   inflating: Kitti/data_road/training/calib/um_000078.txt
#   inflating: Kitti/data_road/training/calib/um_000079.txt
#   inflating: Kitti/data_road/training/calib/um_000080.txt
#   inflating: Kitti/data_road/training/calib/um_000081.txt
#   inflating: Kitti/data_road/training/calib/um_000082.txt
#   inflating: Kitti/data_road/training/calib/um_000083.txt
#   inflating: Kitti/data_road/training/calib/um_000084.txt
#   inflating: Kitti/data_road/training/calib/um_000085.txt
#   inflating: Kitti/data_road/training/calib/um_000086.txt
#   inflating: Kitti/data_road/training/calib/um_000087.txt
#   inflating: Kitti/data_road/training/calib/um_000088.txt
#   inflating: Kitti/data_road/training/calib/um_000089.txt
#   inflating: Kitti/data_road/training/calib/um_000090.txt
#   inflating: Kitti/data_road/training/calib/um_000091.txt
#   inflating: Kitti/data_road/training/calib/um_000092.txt
#   inflating: Kitti/data_road/training/calib/um_000093.txt
#   inflating: Kitti/data_road/training/calib/um_000094.txt
#   inflating: Kitti/data_road/training/calib/umm_000000.txt
#   inflating: Kitti/data_road/training/calib/umm_000001.txt
#   inflating: Kitti/data_road/training/calib/umm_000002.txt
#   inflating: Kitti/data_road/training/calib/umm_000003.txt
#   inflating: Kitti/data_road/training/calib/umm_000004.txt
#   inflating: Kitti/data_road/training/calib/umm_000005.txt
#   inflating: Kitti/data_road/training/calib/umm_000006.txt
#   inflating: Kitti/data_road/training/calib/umm_000007.txt
#   inflating: Kitti/data_road/training/calib/umm_000008.txt
#   inflating: Kitti/data_road/training/calib/umm_000009.txt
#   inflating: Kitti/data_road/training/calib/umm_000010.txt
#   inflating: Kitti/data_road/training/calib/umm_000011.txt
#   inflating: Kitti/data_road/training/calib/umm_000012.txt
#   inflating: Kitti/data_road/training/calib/umm_000013.txt
#   inflating: Kitti/data_road/training/calib/umm_000014.txt
#   inflating: Kitti/data_road/training/calib/umm_000015.txt
#   inflating: Kitti/data_road/training/calib/umm_000016.txt
#   inflating: Kitti/data_road/training/calib/umm_000017.txt
#   inflating: Kitti/data_road/training/calib/umm_000018.txt
#   inflating: Kitti/data_road/training/calib/umm_000019.txt
#   inflating: Kitti/data_road/training/calib/umm_000020.txt
#   inflating: Kitti/data_road/training/calib/umm_000021.txt
#   inflating: Kitti/data_road/training/calib/umm_000022.txt
#   inflating: Kitti/data_road/training/calib/umm_000023.txt
#   inflating: Kitti/data_road/training/calib/umm_000024.txt
#   inflating: Kitti/data_road/training/calib/umm_000025.txt
#   inflating: Kitti/data_road/training/calib/umm_000026.txt
#   inflating: Kitti/data_road/training/calib/umm_000027.txt
#   inflating: Kitti/data_road/training/calib/umm_000028.txt
#   inflating: Kitti/data_road/training/calib/umm_000029.txt
#   inflating: Kitti/data_road/training/calib/umm_000030.txt
#   inflating: Kitti/data_road/training/calib/umm_000031.txt
#   inflating: Kitti/data_road/training/calib/umm_000032.txt
#   inflating: Kitti/data_road/training/calib/umm_000033.txt
#   inflating: Kitti/data_road/training/calib/umm_000034.txt
#   inflating: Kitti/data_road/training/calib/umm_000035.txt
#   inflating: Kitti/data_road/training/calib/umm_000036.txt
#   inflating: Kitti/data_road/training/calib/umm_000037.txt
#   inflating: Kitti/data_road/training/calib/umm_000038.txt
#   inflating: Kitti/data_road/training/calib/umm_000039.txt
#   inflating: Kitti/data_road/training/calib/umm_000040.txt
#   inflating: Kitti/data_road/training/calib/umm_000041.txt
#   inflating: Kitti/data_road/training/calib/umm_000042.txt
#   inflating: Kitti/data_road/training/calib/umm_000043.txt
#   inflating: Kitti/data_road/training/calib/umm_000044.txt
#   inflating: Kitti/data_road/training/calib/umm_000045.txt
#   inflating: Kitti/data_road/training/calib/umm_000046.txt
#   inflating: Kitti/data_road/training/calib/umm_000047.txt
#   inflating: Kitti/data_road/training/calib/umm_000048.txt
#   inflating: Kitti/data_road/training/calib/umm_000049.txt
#   inflating: Kitti/data_road/training/calib/umm_000050.txt
#   inflating: Kitti/data_road/training/calib/umm_000051.txt
#   inflating: Kitti/data_road/training/calib/umm_000052.txt
#   inflating: Kitti/data_road/training/calib/umm_000053.txt
#   inflating: Kitti/data_road/training/calib/umm_000054.txt
#   inflating: Kitti/data_road/training/calib/umm_000055.txt
#   inflating: Kitti/data_road/training/calib/umm_000056.txt
#   inflating: Kitti/data_road/training/calib/umm_000057.txt
#   inflating: Kitti/data_road/training/calib/umm_000058.txt
#   inflating: Kitti/data_road/training/calib/umm_000059.txt
#   inflating: Kitti/data_road/training/calib/umm_000060.txt
#   inflating: Kitti/data_road/training/calib/umm_000061.txt
#   inflating: Kitti/data_road/training/calib/umm_000062.txt
#   inflating: Kitti/data_road/training/calib/umm_000063.txt
#   inflating: Kitti/data_road/training/calib/umm_000064.txt
#   inflating: Kitti/data_road/training/calib/umm_000065.txt
#   inflating: Kitti/data_road/training/calib/umm_000066.txt
#   inflating: Kitti/data_road/training/calib/umm_000067.txt
#   inflating: Kitti/data_road/training/calib/umm_000068.txt
#   inflating: Kitti/data_road/training/calib/umm_000069.txt
#   inflating: Kitti/data_road/training/calib/umm_000070.txt
#   inflating: Kitti/data_road/training/calib/umm_000071.txt
#   inflating: Kitti/data_road/training/calib/umm_000072.txt
#   inflating: Kitti/data_road/training/calib/umm_000073.txt
#   inflating: Kitti/data_road/training/calib/umm_000074.txt
#   inflating: Kitti/data_road/training/calib/umm_000075.txt
#   inflating: Kitti/data_road/training/calib/umm_000076.txt
#   inflating: Kitti/data_road/training/calib/umm_000077.txt
#   inflating: Kitti/data_road/training/calib/umm_000078.txt
#   inflating: Kitti/data_road/training/calib/umm_000079.txt
#   inflating: Kitti/data_road/training/calib/umm_000080.txt
#   inflating: Kitti/data_road/training/calib/umm_000081.txt
#   inflating: Kitti/data_road/training/calib/umm_000082.txt
#   inflating: Kitti/data_road/training/calib/umm_000083.txt
#   inflating: Kitti/data_road/training/calib/umm_000084.txt
#   inflating: Kitti/data_road/training/calib/umm_000085.txt
#   inflating: Kitti/data_road/training/calib/umm_000086.txt
#   inflating: Kitti/data_road/training/calib/umm_000087.txt
#   inflating: Kitti/data_road/training/calib/umm_000088.txt
#   inflating: Kitti/data_road/training/calib/umm_000089.txt
#   inflating: Kitti/data_road/training/calib/umm_000090.txt
#   inflating: Kitti/data_road/training/calib/umm_000091.txt
#   inflating: Kitti/data_road/training/calib/umm_000092.txt
# ...
#   inflating: Kitti/data_road/training/image_2/um_000035.png
#   inflating: Kitti/data_road/training/image_2/um_000036.png
#   inflating: Kitti/data_road/training/image_2/um_000037.png
#   inflating: Kitti/data_road/training/image_2/um_000038.png
#   inflating: Kitti/data_road/training/image_2/um_000039.png
#   inflating: Kitti/data_road/training/image_2/um_000040.png
#   inflating: Kitti/data_road/training/image_2/um_000041.png
#   inflating: Kitti/data_road/training/image_2/um_000042.png
#   inflating: Kitti/data_road/training/image_2/um_000043.png
#   inflating: Kitti/data_road/training/image_2/um_000044.png
#   inflating: Kitti/data_road/training/image_2/um_000045.png
#   inflating: Kitti/data_road/training/image_2/um_000046.png
#   inflating: Kitti/data_road/training/image_2/um_000047.png
#   inflating: Kitti/data_road/training/image_2/um_000048.png
#   inflating: Kitti/data_road/training/image_2/um_000049.png
#   inflating: Kitti/data_road/training/image_2/um_000050.png
#   inflating: Kitti/data_road/training/image_2/um_000051.png
#   inflating: Kitti/data_road/training/image_2/um_000052.png
#   inflating: Kitti/data_road/training/image_2/um_000053.png
#   inflating: Kitti/data_road/training/image_2/um_000054.png
#   inflating: Kitti/data_road/training/image_2/um_000055.png
#   inflating: Kitti/data_road/training/image_2/um_000056.png
#   inflating: Kitti/data_road/training/image_2/um_000057.png
#   inflating: Kitti/data_road/training/image_2/um_000058.png
#   inflating: Kitti/data_road/training/image_2/um_000059.png
#   inflating: Kitti/data_road/training/image_2/um_000060.png
#   inflating: Kitti/data_road/training/image_2/um_000061.png
#   inflating: Kitti/data_road/training/image_2/um_000062.png
#   inflating: Kitti/data_road/training/image_2/um_000063.png
#   inflating: Kitti/data_road/training/image_2/um_000064.png
#   inflating: Kitti/data_road/training/image_2/um_000065.png
#   inflating: Kitti/data_road/training/image_2/um_000066.png
#   inflating: Kitti/data_road/training/image_2/um_000067.png
#   inflating: Kitti/data_road/training/image_2/um_000068.png
#   inflating: Kitti/data_road/training/image_2/um_000069.png
#   inflating: Kitti/data_road/training/image_2/um_000070.png
#   inflating: Kitti/data_road/training/image_2/um_000071.png
#   inflating: Kitti/data_road/training/image_2/um_000072.png
#   inflating: Kitti/data_road/training/image_2/um_000073.png
#   inflating: Kitti/data_road/training/image_2/um_000074.png
#   inflating: Kitti/data_road/training/image_2/um_000075.png
#   inflating: Kitti/data_road/training/image_2/um_000076.png
#   inflating: Kitti/data_road/training/image_2/um_000077.png
#   inflating: Kitti/data_road/training/image_2/um_000078.png
#   inflating: Kitti/data_road/training/image_2/um_000079.png
#   inflating: Kitti/data_road/training/image_2/um_000080.png
#   inflating: Kitti/data_road/training/image_2/um_000081.png
#   inflating: Kitti/data_road/training/image_2/um_000082.png
#   inflating: Kitti/data_road/training/image_2/um_000083.png
#   inflating: Kitti/data_road/training/image_2/um_000084.png
#   inflating: Kitti/data_road/training/image_2/um_000085.png
#   inflating: Kitti/data_road/training/image_2/um_000086.png
#   inflating: Kitti/data_road/training/image_2/um_000087.png
#   inflating: Kitti/data_road/training/image_2/um_000088.png
#   inflating: Kitti/data_road/training/image_2/um_000089.png
#   inflating: Kitti/data_road/training/image_2/um_000090.png
#   inflating: Kitti/data_road/training/image_2/um_000091.png
#   inflating: Kitti/data_road/training/image_2/um_000092.png
#   inflating: Kitti/data_road/training/image_2/um_000093.png
#   inflating: Kitti/data_road/training/image_2/um_000094.png
#   inflating: Kitti/data_road/training/image_2/umm_000000.png
#   inflating: Kitti/data_road/training/image_2/umm_000001.png
#   inflating: Kitti/data_road/training/image_2/umm_000002.png
#   inflating: Kitti/data_road/training/image_2/umm_000003.png
#   inflating: Kitti/data_road/training/image_2/umm_000004.png
#   inflating: Kitti/data_road/training/image_2/umm_000005.png
#   inflating: Kitti/data_road/training/image_2/umm_000006.png
#   inflating: Kitti/data_road/training/image_2/umm_000007.png
#   inflating: Kitti/data_road/training/image_2/umm_000008.png
#   inflating: Kitti/data_road/training/image_2/umm_000009.png
#   inflating: Kitti/data_road/training/image_2/umm_000010.png
#   inflating: Kitti/data_road/training/image_2/umm_000011.png
#   inflating: Kitti/data_road/training/image_2/umm_000012.png
#   inflating: Kitti/data_road/training/image_2/umm_000013.png
#   inflating: Kitti/data_road/training/image_2/umm_000014.png
#   inflating: Kitti/data_road/training/image_2/umm_000015.png
#   inflating: Kitti/data_road/training/image_2/umm_000016.png
#   inflating: Kitti/data_road/training/image_2/umm_000017.png
#   inflating: Kitti/data_road/training/image_2/umm_000018.png
#   inflating: Kitti/data_road/training/image_2/umm_000019.png
#   inflating: Kitti/data_road/training/image_2/umm_000020.png
#   inflating: Kitti/data_road/training/image_2/umm_000021.png
#   inflating: Kitti/data_road/training/image_2/umm_000022.png
#   inflating: Kitti/data_road/training/image_2/umm_000023.png
#   inflating: Kitti/data_road/training/image_2/umm_000024.png
#   inflating: Kitti/data_road/training/image_2/umm_000025.png
#   inflating: Kitti/data_road/training/image_2/umm_000026.png
#   inflating: Kitti/data_road/training/image_2/umm_000027.png
#   inflating: Kitti/data_road/training/image_2/umm_000028.png
#   inflating: Kitti/data_road/training/image_2/umm_000029.png
#   inflating: Kitti/data_road/training/image_2/umm_000030.png
#   inflating: Kitti/data_road/training/image_2/umm_000031.png
#   inflating: Kitti/data_road/training/image_2/umm_000032.png
#   inflating: Kitti/data_road/training/image_2/umm_000033.png
#   inflating: Kitti/data_road/training/image_2/umm_000034.png
#   inflating: Kitti/data_road/training/image_2/umm_000035.png
#   inflating: Kitti/data_road/training/image_2/umm_000036.png
#   inflating: Kitti/data_road/training/image_2/umm_000037.png
#   inflating: Kitti/data_road/training/image_2/umm_000038.png
#   inflating: Kitti/data_road/training/image_2/umm_000039.png
#   inflating: Kitti/data_road/training/image_2/umm_000040.png
#   inflating: Kitti/data_road/training/image_2/umm_000041.png
#   inflating: Kitti/data_road/training/image_2/umm_000042.png
#   inflating: Kitti/data_road/training/image_2/umm_000043.png
#   inflating: Kitti/data_road/training/image_2/umm_000044.png
#   inflating: Kitti/data_road/training/image_2/umm_000045.png
#   inflating: Kitti/data_road/training/image_2/umm_000046.png
#   inflating: Kitti/data_road/training/image_2/umm_000047.png
#   inflating: Kitti/data_road/training/image_2/umm_000048.png
#   inflating: Kitti/data_road/training/image_2/umm_000049.png
#   inflating: Kitti/data_road/training/image_2/umm_000050.png
#   inflating: Kitti/data_road/training/image_2/umm_000051.png
#   inflating: Kitti/data_road/training/image_2/umm_000052.png
#   inflating: Kitti/data_road/training/image_2/umm_000053.png
#   inflating: Kitti/data_road/training/image_2/umm_000054.png
#   inflating: Kitti/data_road/training/image_2/umm_000055.png
#   inflating: Kitti/data_road/training/image_2/umm_000056.png
#   inflating: Kitti/data_road/training/image_2/umm_000057.png
#   inflating: Kitti/data_road/training/image_2/umm_000058.png
#   inflating: Kitti/data_road/training/image_2/umm_000059.png
#   inflating: Kitti/data_road/training/image_2/umm_000060.png
#   inflating: Kitti/data_road/training/image_2/umm_000061.png
#   inflating: Kitti/data_road/training/image_2/umm_000062.png
#   inflating: Kitti/data_road/training/image_2/umm_000063.png
#   inflating: Kitti/data_road/training/image_2/umm_000064.png
#   inflating: Kitti/data_road/training/image_2/umm_000065.png
#   inflating: Kitti/data_road/training/image_2/umm_000066.png
#   inflating: Kitti/data_road/training/image_2/umm_000067.png
#   inflating: Kitti/data_road/training/image_2/umm_000068.png
#   inflating: Kitti/data_road/training/image_2/umm_000069.png
#   inflating: Kitti/data_road/training/image_2/umm_000070.png
#   inflating: Kitti/data_road/training/image_2/umm_000071.png
#   inflating: Kitti/data_road/training/image_2/umm_000072.png
#   inflating: Kitti/data_road/training/image_2/umm_000073.png
#   inflating: Kitti/data_road/training/image_2/umm_000074.png
#   inflating: Kitti/data_road/training/image_2/umm_000075.png
#   inflating: Kitti/data_road/training/image_2/umm_000076.png
#   inflating: Kitti/data_road/training/image_2/umm_000077.png
#   inflating: Kitti/data_road/training/image_2/umm_000078.png
#   inflating: Kitti/data_road/training/image_2/umm_000079.png
#   inflating: Kitti/data_road/training/image_2/umm_000080.png
#   inflating: Kitti/data_road/training/image_2/umm_000081.png
#   inflating: Kitti/data_road/training/image_2/umm_000082.png
#   inflating: Kitti/data_road/training/image_2/umm_000083.png
#   inflating: Kitti/data_road/training/image_2/umm_000084.png
#   inflating: Kitti/data_road/training/image_2/umm_000085.png
#   inflating: Kitti/data_road/training/image_2/umm_000086.png
#   inflating: Kitti/data_road/training/image_2/umm_000087.png
#   inflating: Kitti/data_road/training/image_2/umm_000088.png
#   inflating: Kitti/data_road/training/image_2/umm_000089.png
#   inflating: Kitti/data_road/training/image_2/umm_000090.png
#   inflating: Kitti/data_road/training/image_2/umm_000091.png
#   inflating: Kitti/data_road/training/image_2/umm_000092.png
#   inflating: Kitti/data_road/training/image_2/umm_000093.png
#   inflating: Kitti/data_road/training/image_2/umm_000094.png
#   inflating: Kitti/data_road/training/image_2/umm_000095.png
#   inflating: Kitti/data_road/training/image_2/uu_000000.png
#   inflating: Kitti/data_road/training/image_2/uu_000001.png
#   inflating: Kitti/data_road/training/image_2/uu_000002.png
#   inflating: Kitti/data_road/training/image_2/uu_000003.png
#   inflating: Kitti/data_road/training/image_2/uu_000004.png
#   inflating: Kitti/data_road/training/image_2/uu_000005.png
#   inflating: Kitti/data_road/training/image_2/uu_000006.png
#   inflating: Kitti/data_road/training/image_2/uu_000007.png
#   inflating: Kitti/data_road/training/image_2/uu_000008.png
#   inflating: Kitti/data_road/training/image_2/uu_000009.png
#   inflating: Kitti/data_road/training/image_2/uu_000010.png
#   inflating: Kitti/data_road/training/image_2/uu_000011.png
#   inflating: Kitti/data_road/training/image_2/uu_000012.png
#   inflating: Kitti/data_road/training/image_2/uu_000013.png
#   inflating: Kitti/data_road/training/image_2/uu_000014.png
#   inflating: Kitti/data_road/training/image_2/uu_000015.png
#   inflating: Kitti/data_road/training/image_2/uu_000016.png
#   inflating: Kitti/data_road/training/image_2/uu_000017.png
#   inflating: Kitti/data_road/training/image_2/uu_000018.png
#   inflating: Kitti/data_road/training/image_2/uu_000019.png
#   inflating: Kitti/data_road/training/image_2/uu_000020.png
#   inflating: Kitti/data_road/training/image_2/uu_000021.png
#   inflating: Kitti/data_road/training/image_2/uu_000022.png
#   inflating: Kitti/data_road/training/image_2/uu_000023.png
#   inflating: Kitti/data_road/training/image_2/uu_000024.png
#   inflating: Kitti/data_road/training/image_2/uu_000025.png
#   inflating: Kitti/data_road/training/image_2/uu_000026.png
#   inflating: Kitti/data_road/training/image_2/uu_000027.png
#   inflating: Kitti/data_road/training/image_2/uu_000028.png
#   inflating: Kitti/data_road/training/image_2/uu_000029.png
#   inflating: Kitti/data_road/training/image_2/uu_000030.png
#   inflating: Kitti/data_road/training/image_2/uu_000031.png
#   inflating: Kitti/data_road/training/image_2/uu_000032.png
#   inflating: Kitti/data_road/training/image_2/uu_000033.png
#   inflating: Kitti/data_road/training/image_2/uu_000034.png
#   inflating: Kitti/data_road/training/image_2/uu_000035.png
#   inflating: Kitti/data_road/training/image_2/uu_000036.png
#   inflating: Kitti/data_road/training/image_2/uu_000037.png
#   inflating: Kitti/data_road/training/image_2/uu_000038.png
#   inflating: Kitti/data_road/training/image_2/uu_000039.png
#   inflating: Kitti/data_road/training/image_2/uu_000040.png
#   inflating: Kitti/data_road/training/image_2/uu_000041.png
#   inflating: Kitti/data_road/training/image_2/uu_000042.png
#   inflating: Kitti/data_road/training/image_2/uu_000043.png
#   inflating: Kitti/data_road/training/image_2/uu_000044.png
#   inflating: Kitti/data_road/training/image_2/uu_000045.png
#   inflating: Kitti/data_road/training/image_2/uu_000046.png
#   inflating: Kitti/data_road/training/image_2/uu_000047.png
#   inflating: Kitti/data_road/training/image_2/uu_000048.png
#   inflating: Kitti/data_road/training/image_2/uu_000049.png
#   inflating: Kitti/data_road/training/image_2/uu_000050.png
#   inflating: Kitti/data_road/training/image_2/uu_000051.png
#   inflating: Kitti/data_road/training/image_2/uu_000052.png
#   inflating: Kitti/data_road/training/image_2/uu_000053.png
#   inflating: Kitti/data_road/training/image_2/uu_000054.png
#   inflating: Kitti/data_road/training/image_2/uu_000055.png
#   inflating: Kitti/data_road/training/image_2/uu_000056.png
#   inflating: Kitti/data_road/training/image_2/uu_000057.png
#   inflating: Kitti/data_road/training/image_2/uu_000058.png
#   inflating: Kitti/data_road/training/image_2/uu_000059.png
#   inflating: Kitti/data_road/training/image_2/uu_000060.png
#   inflating: Kitti/data_road/training/image_2/uu_000061.png
#   inflating: Kitti/data_road/training/image_2/uu_000062.png
#   inflating: Kitti/data_road/training/image_2/uu_000063.png
#   inflating: Kitti/data_road/training/image_2/uu_000064.png
#   inflating: Kitti/data_road/training/image_2/uu_000065.png
#   inflating: Kitti/data_road/training/image_2/uu_000066.png
#   inflating: Kitti/data_road/training/image_2/uu_000067.png
#   inflating: Kitti/data_road/training/image_2/uu_000068.png
#   inflating: Kitti/data_road/training/image_2/uu_000069.png
#   inflating: Kitti/data_road/training/image_2/uu_000070.png
#   inflating: Kitti/data_road/training/image_2/uu_000071.png
#   inflating: Kitti/data_road/training/image_2/uu_000072.png
#   inflating: Kitti/data_road/training/image_2/uu_000073.png
#   inflating: Kitti/data_road/training/image_2/uu_000074.png
#   inflating: Kitti/data_road/training/image_2/uu_000075.png
#   inflating: Kitti/data_road/training/image_2/uu_000076.png
#   inflating: Kitti/data_road/training/image_2/uu_000077.png
#   inflating: Kitti/data_road/training/image_2/uu_000078.png
#   inflating: Kitti/data_road/training/image_2/uu_000079.png
#   inflating: Kitti/data_road/training/image_2/uu_000080.png
#   inflating: Kitti/data_road/training/image_2/uu_000081.png
#   inflating: Kitti/data_road/training/image_2/uu_000082.png
#   inflating: Kitti/data_road/training/image_2/uu_000083.png
#   inflating: Kitti/data_road/training/image_2/uu_000084.png
#   inflating: Kitti/data_road/training/image_2/uu_000085.png
#   inflating: Kitti/data_road/training/image_2/uu_000086.png
#   inflating: Kitti/data_road/training/image_2/uu_000087.png
#   inflating: Kitti/data_road/training/image_2/uu_000088.png
#   inflating: Kitti/data_road/training/image_2/uu_000089.png
#   inflating: Kitti/data_road/training/image_2/uu_000090.png
#   inflating: Kitti/data_road/training/image_2/uu_000091.png
#   inflating: Kitti/data_road/training/image_2/uu_000092.png
#   inflating: Kitti/data_road/training/image_2/uu_000093.png
#   inflating: Kitti/data_road/training/image_2/uu_000094.png
#   inflating: Kitti/data_road/training/image_2/uu_000095.png
#   inflating: Kitti/data_road/training/image_2/uu_000096.png
#   inflating: Kitti/data_road/training/image_2/uu_000097.png
#   inflating: Kitti/test.txt
#   inflating: Kitti/train.txt
#   inflating: Kitti/val.txt

# %% [markdown]
# # Dataloader

# %%
imgsets_file = osp.join('Kitti', '{}.txt'.format('train'))
for line in open(imgsets_file):
    line = line.strip()
    print(line)
    line = line.split()
# Out:
# training/image_2/um_000000.png training/gt_image_2/um_road_000000.png
# training/image_2/um_000001.png training/gt_image_2/um_road_000001.png
# training/image_2/um_000002.png training/gt_image_2/um_road_000002.png
# training/image_2/um_000003.png training/gt_image_2/um_road_000003.png
# training/image_2/um_000004.png training/gt_image_2/um_road_000004.png
# training/image_2/um_000005.png training/gt_image_2/um_road_000005.png
# training/image_2/um_000006.png training/gt_image_2/um_road_000006.png
# training/image_2/um_000007.png training/gt_image_2/um_road_000007.png
# training/image_2/um_000008.png training/gt_image_2/um_road_000008.png
# training/image_2/um_000009.png training/gt_image_2/um_road_000009.png
# training/image_2/um_000010.png training/gt_image_2/um_road_000010.png
# training/image_2/um_000011.png training/gt_image_2/um_road_000011.png
# training/image_2/um_000012.png training/gt_image_2/um_road_000012.png
# training/image_2/um_000013.png training/gt_image_2/um_road_000013.png
# training/image_2/um_000014.png training/gt_image_2/um_road_000014.png
# training/image_2/um_000015.png training/gt_image_2/um_road_000015.png
# training/image_2/um_000016.png training/gt_image_2/um_road_000016.png
# training/image_2/um_000017.png training/gt_image_2/um_road_000017.png
# training/image_2/um_000018.png training/gt_image_2/um_road_000018.png
# training/image_2/um_000019.png training/gt_image_2/um_road_000019.png
# training/image_2/um_000020.png training/gt_image_2/um_road_000020.png
# training/image_2/um_000021.png training/gt_image_2/um_road_000021.png
# training/image_2/um_000022.png training/gt_image_2/um_road_000022.png
# training/image_2/um_000023.png training/gt_image_2/um_road_000023.png
# training/image_2/um_000024.png training/gt_image_2/um_road_000024.png
# training/image_2/um_000025.png training/gt_image_2/um_road_000025.png
# training/image_2/um_000026.png training/gt_image_2/um_road_000026.png
# training/image_2/um_000027.png training/gt_image_2/um_road_000027.png
# training/image_2/um_000028.png training/gt_image_2/um_road_000028.png
# training/image_2/um_000029.png training/gt_image_2/um_road_000029.png
# training/image_2/um_000030.png training/gt_image_2/um_road_000030.png
# training/image_2/um_000031.png training/gt_image_2/um_road_000031.png
# training/image_2/um_000032.png training/gt_image_2/um_road_000032.png
# training/image_2/um_000033.png training/gt_image_2/um_road_000033.png
# training/image_2/um_000034.png training/gt_image_2/um_road_000034.png
# training/image_2/um_000035.png training/gt_image_2/um_road_000035.png
# training/image_2/um_000036.png training/gt_image_2/um_road_000036.png
# training/image_2/um_000037.png training/gt_image_2/um_road_000037.png
# training/image_2/um_000038.png training/gt_image_2/um_road_000038.png
# training/image_2/um_000039.png training/gt_image_2/um_road_000039.png
# training/image_2/um_000040.png training/gt_image_2/um_road_000040.png
# training/image_2/um_000041.png training/gt_image_2/um_road_000041.png
# training/image_2/um_000042.png training/gt_image_2/um_road_000042.png
# training/image_2/um_000043.png training/gt_image_2/um_road_000043.png
# training/image_2/um_000044.png training/gt_image_2/um_road_000044.png
# training/image_2/um_000045.png training/gt_image_2/um_road_000045.png
# training/image_2/um_000046.png training/gt_image_2/um_road_000046.png
# training/image_2/um_000047.png training/gt_image_2/um_road_000047.png
# training/image_2/um_000048.png training/gt_image_2/um_road_000048.png
# training/image_2/um_000049.png training/gt_image_2/um_road_000049.png
# training/image_2/um_000050.png training/gt_image_2/um_road_000050.png
# training/image_2/um_000051.png training/gt_image_2/um_road_000051.png
# training/image_2/um_000052.png training/gt_image_2/um_road_000052.png
# training/image_2/um_000053.png training/gt_image_2/um_road_000053.png
# training/image_2/um_000054.png training/gt_image_2/um_road_000054.png
# training/image_2/um_000055.png training/gt_image_2/um_road_000055.png
# training/image_2/um_000056.png training/gt_image_2/um_road_000056.png
# training/image_2/um_000057.png training/gt_image_2/um_road_000057.png
# training/image_2/um_000058.png training/gt_image_2/um_road_000058.png
# training/image_2/um_000059.png training/gt_image_2/um_road_000059.png
# training/image_2/um_000060.png training/gt_image_2/um_road_000060.png
# training/image_2/um_000061.png training/gt_image_2/um_road_000061.png
# training/image_2/um_000062.png training/gt_image_2/um_road_000062.png
# training/image_2/um_000063.png training/gt_image_2/um_road_000063.png
# training/image_2/um_000064.png training/gt_image_2/um_road_000064.png
# training/image_2/um_000065.png training/gt_image_2/um_road_000065.png
# training/image_2/um_000066.png training/gt_image_2/um_road_000066.png
# training/image_2/um_000067.png training/gt_image_2/um_road_000067.png
# training/image_2/um_000068.png training/gt_image_2/um_road_000068.png
# training/image_2/um_000069.png training/gt_image_2/um_road_000069.png
# training/image_2/um_000070.png training/gt_image_2/um_road_000070.png
# training/image_2/um_000071.png training/gt_image_2/um_road_000071.png
# training/image_2/um_000072.png training/gt_image_2/um_road_000072.png
# training/image_2/um_000073.png training/gt_image_2/um_road_000073.png
# training/image_2/um_000074.png training/gt_image_2/um_road_000074.png
# training/image_2/um_000075.png training/gt_image_2/um_road_000075.png
# training/image_2/um_000076.png training/gt_image_2/um_road_000076.png
# training/image_2/um_000077.png training/gt_image_2/um_road_000077.png
# training/image_2/um_000078.png training/gt_image_2/um_road_000078.png
# training/image_2/umm_000000.png training/gt_image_2/umm_road_000000.png
# training/image_2/umm_000001.png training/gt_image_2/umm_road_000001.png
# training/image_2/umm_000002.png training/gt_image_2/umm_road_000002.png
# training/image_2/umm_000003.png training/gt_image_2/umm_road_000003.png
# training/image_2/umm_000004.png training/gt_image_2/umm_road_000004.png
# training/image_2/umm_000005.png training/gt_image_2/umm_road_000005.png
# training/image_2/umm_000006.png training/gt_image_2/umm_road_000006.png
# training/image_2/umm_000007.png training/gt_image_2/umm_road_000007.png
# training/image_2/umm_000008.png training/gt_image_2/umm_road_000008.png
# training/image_2/umm_000009.png training/gt_image_2/umm_road_000009.png
# training/image_2/umm_000010.png training/gt_image_2/umm_road_000010.png
# training/image_2/umm_000011.png training/gt_image_2/umm_road_000011.png
# training/image_2/umm_000012.png training/gt_image_2/umm_road_000012.png
# training/image_2/umm_000013.png training/gt_image_2/umm_road_000013.png
# training/image_2/umm_000014.png training/gt_image_2/umm_road_000014.png
# training/image_2/umm_000015.png training/gt_image_2/umm_road_000015.png
# training/image_2/umm_000016.png training/gt_image_2/umm_road_000016.png
# training/image_2/umm_000017.png training/gt_image_2/umm_road_000017.png
# training/image_2/umm_000018.png training/gt_image_2/umm_road_000018.png
# training/image_2/umm_000019.png training/gt_image_2/umm_road_000019.png
# training/image_2/umm_000020.png training/gt_image_2/umm_road_000020.png
# training/image_2/umm_000021.png training/gt_image_2/umm_road_000021.png
# training/image_2/umm_000022.png training/gt_image_2/umm_road_000022.png
# training/image_2/umm_000023.png training/gt_image_2/umm_road_000023.png
# training/image_2/umm_000024.png training/gt_image_2/umm_road_000024.png
# training/image_2/umm_000025.png training/gt_image_2/umm_road_000025.png
# training/image_2/umm_000026.png training/gt_image_2/umm_road_000026.png
# training/image_2/umm_000027.png training/gt_image_2/umm_road_000027.png
# training/image_2/umm_000028.png training/gt_image_2/umm_road_000028.png
# training/image_2/umm_000029.png training/gt_image_2/umm_road_000029.png
# training/image_2/umm_000030.png training/gt_image_2/umm_road_000030.png
# training/image_2/umm_000031.png training/gt_image_2/umm_road_000031.png
# training/image_2/umm_000032.png training/gt_image_2/umm_road_000032.png
# training/image_2/umm_000033.png training/gt_image_2/umm_road_000033.png
# training/image_2/umm_000034.png training/gt_image_2/umm_road_000034.png
# training/image_2/umm_000035.png training/gt_image_2/umm_road_000035.png
# training/image_2/umm_000036.png training/gt_image_2/umm_road_000036.png
# training/image_2/umm_000037.png training/gt_image_2/umm_road_000037.png
# training/image_2/umm_000038.png training/gt_image_2/umm_road_000038.png
# training/image_2/umm_000039.png training/gt_image_2/umm_road_000039.png
# training/image_2/umm_000040.png training/gt_image_2/umm_road_000040.png
# training/image_2/umm_000041.png training/gt_image_2/umm_road_000041.png
# training/image_2/umm_000042.png training/gt_image_2/umm_road_000042.png
# training/image_2/umm_000043.png training/gt_image_2/umm_road_000043.png
# training/image_2/umm_000044.png training/gt_image_2/umm_road_000044.png
# training/image_2/umm_000045.png training/gt_image_2/umm_road_000045.png
# training/image_2/umm_000046.png training/gt_image_2/umm_road_000046.png
# training/image_2/umm_000047.png training/gt_image_2/umm_road_000047.png
# training/image_2/umm_000048.png training/gt_image_2/umm_road_000048.png
# training/image_2/umm_000049.png training/gt_image_2/umm_road_000049.png
# training/image_2/umm_000050.png training/gt_image_2/umm_road_000050.png
# training/image_2/umm_000051.png training/gt_image_2/umm_road_000051.png
# training/image_2/umm_000052.png training/gt_image_2/umm_road_000052.png
# training/image_2/umm_000053.png training/gt_image_2/umm_road_000053.png
# training/image_2/umm_000054.png training/gt_image_2/umm_road_000054.png
# training/image_2/umm_000055.png training/gt_image_2/umm_road_000055.png
# training/image_2/umm_000056.png training/gt_image_2/umm_road_000056.png
# training/image_2/umm_000057.png training/gt_image_2/umm_road_000057.png
# training/image_2/umm_000058.png training/gt_image_2/umm_road_000058.png
# training/image_2/umm_000059.png training/gt_image_2/umm_road_000059.png
# training/image_2/umm_000060.png training/gt_image_2/umm_road_000060.png
# training/image_2/umm_000061.png training/gt_image_2/umm_road_000061.png
# training/image_2/umm_000062.png training/gt_image_2/umm_road_000062.png
# training/image_2/umm_000063.png training/gt_image_2/umm_road_000063.png
# training/image_2/umm_000064.png training/gt_image_2/umm_road_000064.png
# training/image_2/umm_000065.png training/gt_image_2/umm_road_000065.png
# training/image_2/umm_000066.png training/gt_image_2/umm_road_000066.png
# training/image_2/umm_000067.png training/gt_image_2/umm_road_000067.png
# training/image_2/umm_000068.png training/gt_image_2/umm_road_000068.png
# training/image_2/umm_000069.png training/gt_image_2/umm_road_000069.png
# training/image_2/umm_000070.png training/gt_image_2/umm_road_000070.png
# training/image_2/umm_000071.png training/gt_image_2/umm_road_000071.png
# training/image_2/umm_000072.png training/gt_image_2/umm_road_000072.png
# training/image_2/umm_000073.png training/gt_image_2/umm_road_000073.png
# training/image_2/umm_000074.png training/gt_image_2/umm_road_000074.png
# training/image_2/umm_000075.png training/gt_image_2/umm_road_000075.png
# training/image_2/umm_000076.png training/gt_image_2/umm_road_000076.png
# training/image_2/umm_000077.png training/gt_image_2/umm_road_000077.png
# training/image_2/umm_000078.png training/gt_image_2/umm_road_000078.png
# training/image_2/umm_000079.png training/gt_image_2/umm_road_000079.png
# training/image_2/uu_000000.png training/gt_image_2/uu_road_000000.png
# training/image_2/uu_000001.png training/gt_image_2/uu_road_000001.png
# training/image_2/uu_000002.png training/gt_image_2/uu_road_000002.png
# training/image_2/uu_000003.png training/gt_image_2/uu_road_000003.png
# training/image_2/uu_000004.png training/gt_image_2/uu_road_000004.png
# training/image_2/uu_000005.png training/gt_image_2/uu_road_000005.png
# training/image_2/uu_000006.png training/gt_image_2/uu_road_000006.png
# training/image_2/uu_000007.png training/gt_image_2/uu_road_000007.png
# training/image_2/uu_000008.png training/gt_image_2/uu_road_000008.png
# training/image_2/uu_000009.png training/gt_image_2/uu_road_000009.png
# training/image_2/uu_000010.png training/gt_image_2/uu_road_000010.png
# training/image_2/uu_000011.png training/gt_image_2/uu_road_000011.png
# training/image_2/uu_000012.png training/gt_image_2/uu_road_000012.png
# training/image_2/uu_000013.png training/gt_image_2/uu_road_000013.png
# training/image_2/uu_000014.png training/gt_image_2/uu_road_000014.png
# training/image_2/uu_000015.png training/gt_image_2/uu_road_000015.png
# training/image_2/uu_000016.png training/gt_image_2/uu_road_000016.png
# training/image_2/uu_000017.png training/gt_image_2/uu_road_000017.png
# training/image_2/uu_000018.png training/gt_image_2/uu_road_000018.png
# training/image_2/uu_000019.png training/gt_image_2/uu_road_000019.png
# training/image_2/uu_000020.png training/gt_image_2/uu_road_000020.png
# training/image_2/uu_000021.png training/gt_image_2/uu_road_000021.png
# training/image_2/uu_000022.png training/gt_image_2/uu_road_000022.png
# training/image_2/uu_000023.png training/gt_image_2/uu_road_000023.png
# training/image_2/uu_000024.png training/gt_image_2/uu_road_000024.png
# training/image_2/uu_000025.png training/gt_image_2/uu_road_000025.png
# training/image_2/uu_000026.png training/gt_image_2/uu_road_000026.png
# training/image_2/uu_000027.png training/gt_image_2/uu_road_000027.png
# training/image_2/uu_000028.png training/gt_image_2/uu_road_000028.png
# training/image_2/uu_000029.png training/gt_image_2/uu_road_000029.png
# training/image_2/uu_000030.png training/gt_image_2/uu_road_000030.png
# training/image_2/uu_000031.png training/gt_image_2/uu_road_000031.png
# training/image_2/uu_000032.png training/gt_image_2/uu_road_000032.png
# training/image_2/uu_000033.png training/gt_image_2/uu_road_000033.png
# training/image_2/uu_000034.png training/gt_image_2/uu_road_000034.png
# training/image_2/uu_000035.png training/gt_image_2/uu_road_000035.png
# training/image_2/uu_000036.png training/gt_image_2/uu_road_000036.png
# training/image_2/uu_000037.png training/gt_image_2/uu_road_000037.png
# training/image_2/uu_000038.png training/gt_image_2/uu_road_000038.png
# training/image_2/uu_000039.png training/gt_image_2/uu_road_000039.png
# training/image_2/uu_000040.png training/gt_image_2/uu_road_000040.png
# training/image_2/uu_000041.png training/gt_image_2/uu_road_000041.png
# training/image_2/uu_000042.png training/gt_image_2/uu_road_000042.png
# training/image_2/uu_000043.png training/gt_image_2/uu_road_000043.png
# training/image_2/uu_000044.png training/gt_image_2/uu_road_000044.png
# training/image_2/uu_000045.png training/gt_image_2/uu_road_000045.png
# training/image_2/uu_000046.png training/gt_image_2/uu_road_000046.png
# training/image_2/uu_000047.png training/gt_image_2/uu_road_000047.png
# training/image_2/uu_000048.png training/gt_image_2/uu_road_000048.png
# training/image_2/uu_000049.png training/gt_image_2/uu_road_000049.png
# training/image_2/uu_000050.png training/gt_image_2/uu_road_000050.png
# training/image_2/uu_000051.png training/gt_image_2/uu_road_000051.png
# training/image_2/uu_000052.png training/gt_image_2/uu_road_000052.png
# training/image_2/uu_000053.png training/gt_image_2/uu_road_000053.png
# training/image_2/uu_000054.png training/gt_image_2/uu_road_000054.png
# training/image_2/uu_000055.png training/gt_image_2/uu_road_000055.png
# training/image_2/uu_000056.png training/gt_image_2/uu_road_000056.png
# training/image_2/uu_000057.png training/gt_image_2/uu_road_000057.png
# training/image_2/uu_000058.png training/gt_image_2/uu_road_000058.png
# training/image_2/uu_000059.png training/gt_image_2/uu_road_000059.png
# training/image_2/uu_000060.png training/gt_image_2/uu_road_000060.png
# training/image_2/uu_000061.png training/gt_image_2/uu_road_000061.png
# training/image_2/uu_000062.png training/gt_image_2/uu_road_000062.png
# training/image_2/uu_000063.png training/gt_image_2/uu_road_000063.png
# training/image_2/uu_000064.png training/gt_image_2/uu_road_000064.png
# training/image_2/uu_000065.png training/gt_image_2/uu_road_000065.png
# training/image_2/uu_000066.png training/gt_image_2/uu_road_000066.png
# training/image_2/uu_000067.png training/gt_image_2/uu_road_000067.png
# training/image_2/uu_000068.png training/gt_image_2/uu_road_000068.png
# training/image_2/uu_000069.png training/gt_image_2/uu_road_000069.png
# training/image_2/uu_000070.png training/gt_image_2/uu_road_000070.png
# training/image_2/uu_000071.png training/gt_image_2/uu_road_000071.png
# training/image_2/uu_000072.png training/gt_image_2/uu_road_000072.png
# training/image_2/uu_000073.png training/gt_image_2/uu_road_000073.png
# training/image_2/uu_000074.png training/gt_image_2/uu_road_000074.png
# training/image_2/uu_000075.png training/gt_image_2/uu_road_000075.png
# training/image_2/uu_000076.png training/gt_image_2/uu_road_000076.png
# training/image_2/uu_000077.png training/gt_image_2/uu_road_000077.png
# training/image_2/uu_000078.png training/gt_image_2/uu_road_000078.png
# training/image_2/uu_000079.png training/gt_image_2/uu_road_000079.png
# training/image_2/uu_000080.png training/gt_image_2/uu_road_000080.png
# training/image_2/uu_000081.png training/gt_image_2/uu_road_000081.png

# %%
class KITTIdataset(torch.utils.data.Dataset):
    class_names = np.array(['background', 'road'])

    def __init__(self, root, transform, split='train'): # root: "./Kitti"
        ## split에 맞는 txt파일 읽어서, 
        ## input image label image경로 리스트로 각각 저장
        self.root = root
        self.transform = transform
        self.split = split
        
        self.images_path = []
        self.ys = []
        
        imgsets_file = osp.join('Kitti', '{}.txt'.format(split)) # train, val
        for line in open(imgsets_file):
            line = line.strip()
            line = line.split()# line[0]: input image path, # line[1]: label image
            img_file = osp.join(root, 'data_road/{}'.format(line[0]))#load image file
            lbl_file = osp.join(root, 'data_road/{}'.format(line[1]))#load label file
            self.images_path.append(img_file)
            self.ys.append(lbl_file)
            
    def __len__(self):
        ## length return
        return len(self.ys)
    
    def __getitem__(self, index):
        ## index에 맞는 image, label image읽어오기
        # load image
        img_file = self.images_path[index]
        img = PIL.Image.open(img_file)
        img = np.array(img)
        
        lbl_file = self.ys[index]
        lbl = PIL.Image.open(lbl_file)
        lbl = np.array(lbl)
        lbl[lbl==255] = 1
        
        # load label
        
        ## black: 0, white: 255 255->1
        ## 0, 1
        
        return self.transform(img), torch.from_numpy(lbl).long()

# %% [markdown]
# ## Define dataset and dataloader

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5))
])
train_dataset = KITTIdataset(root = './Kitti', split = 'train', transform = transform)
val_dataset = KITTIdataset(root = './Kitti', split = 'val', transform = transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = 1, shuffle = True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 1, shuffle = False)

# %%
print(train_dataset[7][0].shape) ## [0]: img tensor, [1]: label tensor
# Out:
# torch.Size([3, 375, 1242])

# %% [markdown]
# # Define the Network
# -VGG16
#
# - FCN model

# %%
import torch.nn as nn
import torch

# Maxpooling with ceil mode

# %%
#Transposed convolution

# %%
class FCN(nn.Module):
    def __init__(self, num_class = 3):
        super(FCN, self).__init__()
        
        #3->64 2 
        #64->128 2
        #128->256 3 conv->relu->conv->relu->conv
        #256->512 3 conv->relu->conv->relu->conv
        #512->512 3 conv->relu->conv->relu->conv
        
        #375*1242 ->575*1442 574*1440
        ## conv1
        self.features1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding = 100),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding =1),
            nn.ReLU())
        
        ## conv2
        self.features2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding = 1),
            nn.ReLU())
        ## self.pool2
        
        ## conv3
        self.features3 = nn.Sequential(
            nn.Conv2d(128, 256, 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding = 1))
        
        ### pool3
        ## conv4
        self.features4 = nn.Sequential(
            nn.Conv2d(256, 512, 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding = 1))
        
        ### pool4
        ## conv5
        self.features5 = nn.Sequential(
            nn.Conv2d(512, 512, 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding = 1))
        
        self.maxpool = nn.MaxPool2d(2, stride=2, ceil_mode=True)
        
        #4096->4096->num_class
        self.classifier = nn.Sequential(
            nn.Conv2d(512, 4096, 7),
            nn.ReLU(),
            nn.Dropout2d(),
            nn.Conv2d(4096, 4096, 1),
            nn.ReLU(),
            nn.Dropout2d(),
            nn.Conv2d(4096, num_class, 1))
        
    
        
        ## pool 5
        ## upsampling transposed convolution
        self.upscore2 = nn.ConvTranspose2d(num_class, num_class, kernel_size=4, stride=2, bias=False)
        self.upscore4 = nn.ConvTranspose2d(num_class, num_class, kernel_size=4, stride=2, bias=False)
        self.upscore8 = nn.ConvTranspose2d(num_class, num_class, kernel_size=16, stride=8, bias=False)
        
        self.score_pool4 = nn.Conv2d(512, num_class, 1)
        self.score_pool3 = nn.Conv2d(256, num_class, 1)
        
        
        self.params = [self.features1, self.features2, self.features3, 
                       self.features4, self.features5]
        

                             
    def forward(self, inputs):
        # input [Batch size, 3, w, h]
        x = self.features1(inputs) #[Batch size, 64, w, h]
        pool1 = self.maxpool(x) #[Batch size, 64, w/2, h/2]
        
        x = self.features2(pool1) #[Batch size, 128, w/2, h/2]
        pool2 = self.maxpool(x) #[Batch size, 128, w/4, h/4]
        
        x = self.features3(pool2) #[Batch size, 256, w/4, h/4]
        pool3 = self.maxpool(x) #[Batch size, 256, w/8, h/8]
        
        x = self.features4(pool3) #[Batch size, 512, w/8, h/8]
        pool4 = self.maxpool(x) #[Batch size, 512, w/16, h/16]
        
        x = self.features5(pool4) #[Batch size, 512, w/16, h/16]
        pool5 = self.maxpool(x) #[Batch size, 512, w/32, h/32]
        
        x = self.classifier(pool5) #[w/32 - 6, h/32 - 6]
        x = self.upscore2(x) ##[w/16 - 10, h/16 - 10]
        
        pool4 = self.score_pool4(pool4)
        pool4 = pool4[:,:, 5:5+x.size()[2], 5:5+x.size()[3]]
        x = torch.add(x, pool4)
        
        x = self.upscore4(x)
        
        pool3 = self.score_pool3(pool3)
        pool3 = pool3[:,:, 9:9+x.size()[2], 9:9+x.size()[3]]
        x = torch.add(x, pool3)
        
        x = self.upscore8(x)
        x = x[:,:, 33:33+inputs.size()[2], 33:33+inputs.size()[3]]
        
        
        ## channel num_class
        return x ## label map [batch, num_class, inputs h, input w]
    
    def copy_params(self, vgg):
        for l1, l2 in zip(vgg.features, self.params):
            if (isinstance(l1, nn.Conv2d) and isinstance(l2, nn.Conv2d)):
                assert l1.weight.size() == l2.weight.size()
                assert l1.bias.size() == l2.bias.size()
                l2.weight.data = l1.weight.data
                l2.bias.data = l1.bias.data

# %%
model = FCN(3)
# # # print(model)
temp_input = torch.rand(1, 3, 1024, 1024)
m1 = nn.ConvTranspose2d(3, 3, kernel_size=4, stride=2, bias=False)
m2 = nn.ConvTranspose2d(3, 3, kernel_size=4, stride=2, bias=False)
m3 = nn.ConvTranspose2d(3, 3, kernel_size=16, stride=8, bias=False)
output = model(temp_input)
print(output.size())
# Out:
# torch.Size([1, 3, 1024, 1024])

# %% [markdown]
# ## Measure accuracy and visualization

# %%
def _fast_hist(label_true, label_pred, n_class):
    ## define mask, histogram
    ## hint : np.bincount
    mask = (label_true >= 0) & (label_true < n_class)
    hist = np.bincount(n_class*label_true[mask].astype(int)+label_pred[mask]
                      , minlength = n_class**2).reshape(n_class, n_class)
    
    return hist

def compute_mean_iou(label_trues, label_preds, n_class): 
    # label_true: [h, w] # label_pred: [h, w] # n_class: 2
    # TO DO : 각 Class 별 Intersection of Union을 계산
    hist = np.zeros((n_class, n_class))
    for lt, lp in zip(label_trues, label_preds):
        hist += _fast_hist(lt.flatten(), lp.flatten(), n_class)
    iu = np.diag(hist)/ (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
    mean_iou = np.nanmean(iu)
        # Hint1 : _fast_hist를 통해 confusion matrix를 구할 수 있다. 
        # Hint2 : 해당 class의 True = confusion matrix의 해당 row 값의 합
        #         해당 class의 Positive = confusion matrix의 해당 column 값의 합 
        #         해당 class의 True_Positive = confusion matrix의 (class, class)의 값
        # Hint3 : iou = True_Positive / True + Positive - True_Positive 

    return mean_iou

def visualization(net, input_img, epoch):
    ## TO DO : image를 network에 넣어 label을 추출
    img = transform(input_img).unsqueeze(0)
    img.cuda()
    
    score = net(img)
    
    _, lbl_pred = score.max(1)
    lbl_pred = lbl_pred.cpu().numpy()
    lbl_pred = np.squeeze(lbl_pred)
    
    
    os.makedirs("./pred", exist_ok = True)
    os.makedirs("./input", exist_ok = True)

    imageio.imsave('./pred/mask_'+str(epoch+1)+'.png', lbl_pred)
    plt.imshow(mpimg.imread('./pred/mask_'+str(epoch+1)+'.png'),cmap='gray') ### visualize predicted label map
    plt.show()
    input_img = np.array(input_img)
    imageio.imsave('./input/input_'+str(epoch+1)+'.png', input_img)
    plt.imshow(mpimg.imread('./input/input_'+str(epoch+1)+'.png'))
    plt.show()

# %%
label_true = np.array([
    [1, 2],
    [2, 3]
])
label_pred = np.array([
    [1, 2],
    [2, 2]
])

compute_mean_iou(label_true, label_pred, 4)
# Out:
# <ipython-input-33-b45bd13173c3>:16: RuntimeWarning: invalid value encountered in true_divide
#   iu = np.diag(hist)/ (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
# 0.5555555555555555

# %% [markdown]
# # Train

# %%
##load pretrained model from torchvision
##pretrained using coco 2017
#net = torchvision.models.segmentation.fcn_resnet50(pretrained = True)
# print(net)
#net.classifier = torchvision.models.segmentation.fcn.FCNHead( 2048, 2)
#net = net.cuda()
#print(net)

# %%
vgg16 = torchvision.models.vgg16(pretrained = True)
net = FCN(num_class = 2)
net.copy_params(vgg16)

net = net.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss() 
optimizer = optim.Adam(net.parameters(), lr=1e-5, weight_decay = 0.0001)

# %%
training_epochs = 5
best_iou = 0
num_class = len(train_loader.dataset.class_names)
j=0

for epoch in range(training_epochs):
    #train
    net.train()
    print ('current epoch : %d'%(epoch))
    running_loss = 0.0
    for batch_idx, (data, target) in enumerate(train_loader):
        # load data, forward
        data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
    
        score = net(data)
        loss = criterion(score, target)
        loss.backward()
        optimizer.step()
    
        if batch_idx % 20 ==0:
            print ('batch : {}, loss : {}'.format(batch_idx, loss.item()))
        j += 1
        
    #validation
    net.eval()
    val_loss = 0
    metrics = []
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(val_loader):
            # load data, forward
            data, target = data.cuda(), target.cuda()
            score = net(data)
            
            # calc val loss, accuracy
            loss = criterion(score, target)

            val_loss += loss.item()

            _, lbl_pred = score.max(1) #[batch, class, h, w] -> [batch, h, w]
            lbl_pred = lbl_pred.cpu().numpy()
            lbl_true = target.cpu().numpy()
            
            for lt, lp in zip(lbl_true, lbl_pred):
                tmp = compute_mean_iou(lt, lp, num_class)
                metrics.append(tmp)
           
    val_loss /= len(val_loader)
    metrics = np.mean(metrics)
    
    print ('val loss : {}, mean_iou : {}'.format(val_loss, metrics))

    ##save model
    if best_iou < metrics:
        best_iou = metrics
        print("Best model saved")
        torch.save(net.state_dict(), './model_best.pth')
    
    ## visualization
    img = PIL.Image.open('./road_sample1.png')
    visualization(net, img, epoch)
print('Finished Training')
# Out:
# current epoch : 0
# batch : 0, loss : 0.692955493927002
# batch : 20, loss : 0.692620575428009
# batch : 40, loss : 0.6920413374900818
# batch : 60, loss : 0.6894384026527405
# batch : 80, loss : 0.6717439889907837
# batch : 100, loss : 0.6256788372993469
# batch : 120, loss : 0.626075267791748
# batch : 140, loss : 0.5987927913665771
# batch : 160, loss : 0.5587637424468994
# batch : 180, loss : 0.5701109766960144
# batch : 200, loss : 0.5202690958976746
# batch : 220, loss : 0.5167742967605591
# batch : 240, loss : 0.5405365824699402
# val loss : 0.5363060788561901, mean_iou : 0.3997727512237277
# Best model saved
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-13bf328caf29> in <module>
#      59     ## visualization
#      60     img = PIL.Image.open('./road_sample1.png')
# ---> 61     visualization(net, img, epoch)
#      62 print('Finished Training')
#
# <ipython-input-35-0280e19e92ab> in visualization(net, input_img, epoch)
#      29     img.cuda()
#      30
# ---> 31     score = net(img)
#      32
#      33     _, lbl_pred = score.max(1)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-24-71530bc242ef> in forward(self, inputs)
#      82     def forward(self, inputs):
#      83         # input [Batch size, 3, w, h]
# ---> 84         x = self.features1(inputs) #[Batch size, 64, w, h]
#      85         pool1 = self.maxpool(x) #[Batch size, 64, w/2, h/2]
#      86
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     445
#     446     def forward(self, input: Tensor) -> Tensor:
# --> 447         return self._conv_forward(input, self.weight, self.bias)
#     448
#     449 class Conv3d(_ConvNd):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     441                             weight, bias, self.stride,
#     442                             _pair(0), self.dilation, self.groups)
# --> 443         return F.conv2d(input, weight, bias, self.stride,
#     444                         self.padding, self.dilation, self.groups)
#     445
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor

# %%
img = PIL.Image.open('./road_sample1.png')
visualization(net, img, epoch)
